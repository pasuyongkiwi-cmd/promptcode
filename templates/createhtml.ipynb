# %%
with open("index.html", "w") as f:
    f.write("""<!DOCTYPE html>
<html>
<head>
    <title>PromptCode</title>
</head>
<body>
    <h1>PromptCode - Code Reviewer</h1>

    <form action="/review" method="post">
        <textarea name="code" rows="15" cols="80"></textarea>
        <br><br>

        <select name="mode">
            <option value="bug">Bug</option>
            <option value="style_docs">Style</option>
            <option value="full">Full</option>
        </select>

        <br><br>
        <button type="submit">Review</button>
    </form>
</body>
</html>
""")

# %%
with open("result.html", "w") as f:
    f.write("""<!DOCTYPE html>
<html>
<body>
    <h1>Result</h1>
    <p>{{ final_result.summary }}</p>
</body>
</html>
""")

# %%
with open("index.html", "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>PromptCode</title>
# </head>
# <body>
#     <h1>PromptCode - Code Reviewer</h1>
#
#     <form action="/review" method="post">
#         <textarea name="code" rows="15" cols="80"></textarea>
#         <br><br>
#
#         <select name="mode">
#             <option value="bug">Bug</option>
#             <option value="style_docs">Style</option>
#             <option value="full">Full</option>
#         </select>
#
#         <br><br>
#         <button type="submit">Review</button>
#     </form>
# </body>
# </html>

# %%
with open("result.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html>
<head>
    <title>Review Result</title>
</head>
<body>
    <h1>Review Result</h1>

    <h2>Summary</h2>
    <p>{{ final_result.summary }}</p>

    <h2>Bugs</h2>
    <ul>
        {% for b in final_result.bugs %}
            <li>{{ b }}</li>
        {% endfor %}
    </ul>

    <h2>Style Issues</h2>
    <ul>
        {% for s in final_result.style_issues %}
            <li>{{ s }}</li>
        {% endfor %}
    </ul>

    <h2>Documentation Issues</h2>
    <ul>
        {% for d in final_result.documentation_issues %}
            <li>{{ d }}</li>
        {% endfor %}
    </ul>

    <h2>Suggestions</h2>
    <ul>
        {% for s in final_result.suggestions %}
            <li>{{ s }}</li>
        {% endfor %}
    </ul>

    <h2>Improved Code</h2>
    <pre>{{ final_result.improved_code }}</pre>

    <h2>Scores</h2>
    <pre>{{ final_result.scores }}</pre>

    <h2>Overall Score</h2>
    <p>{{ final_result.overall_score }}</p>

    <br>
    <a href="/">Back</a>
</body>
</html>
""")

# %%
with open("result.html", "r", encoding="utf-8") as f:
    print(f.read())
# Out:
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Review Result</title>
# </head>
# <body>
#     <h1>Review Result</h1>
#
#     <h2>Summary</h2>
#     <p>{{ final_result.summary }}</p>
#
#     <h2>Bugs</h2>
#     <ul>
#         {% for b in final_result.bugs %}
#             <li>{{ b }}</li>
#         {% endfor %}
#     </ul>
#
#     <h2>Style Issues</h2>
#     <ul>
#         {% for s in final_result.style_issues %}
#             <li>{{ s }}</li>
#         {% endfor %}
#     </ul>
#
#     <h2>Documentation Issues</h2>
#     <ul>
#         {% for d in final_result.documentation_issues %}
#             <li>{{ d }}</li>
#         {% endfor %}
#     </ul>
#
#     <h2>Suggestions</h2>
#     <ul>
#         {% for s in final_result.suggestions %}
#             <li>{{ s }}</li>
#         {% endfor %}
#     </ul>
#
#     <h2>Improved Code</h2>
#     <pre>{{ final_result.improved_code }}</pre>
#
#     <h2>Scores</h2>
#     <pre>{{ final_result.scores }}</pre>
#
#     <h2>Overall Score</h2>
# ...

# %%
with open("result.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html>
<head>
    <title>Review Result</title>
</head>
<body>
    <h1>Review Result</h1>

    <h2>Summary</h2>
    <p>{{ final_result.summary }}</p>

    <h2>Bugs</h2>
    <ul>
        {% for b in final_result.bugs %}
            <li>{{ b }}</li>
        {% endfor %}
    </ul>

    <h2>Style Issues</h2>
    <ul>
        {% for s in final_result.style_issues %}
            <li>{{ s }}</li>
        {% endfor %}
    </ul>

    <h2>Maintainability Issues</h2>
    <ul>
        {% for m in final_result.maintainability_issues %}
            <li>{{ m }}</li>
        {% endfor %}
    </ul>

    <h2>Documentation Issues</h2>
    <ul>
        {% for d in final_result.documentation_issues %}
            <li>{{ d }}</li>
        {% endfor %}
    </ul>

    <h2>Suggestions</h2>
    <ul>
        {% for s in final_result.suggestions %}
            <li>{{ s }}</li>
        {% endfor %}
    </ul>

    <h2>Improved Code</h2>
    <pre>{{ final_result.improved_code }}</pre>

    <h2>Scores</h2>
    <pre>{{ final_result.scores }}</pre>

    <h2>Overall Score</h2>
    <p>{{ final_result.overall_score }}</p>

    <br>
    <a href="/">Back</a>
</body>
</html>
""")

# %%
with open("result.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html>
<head>
    <title>Review Result</title>
    <style>
        body { font-family: Arial; margin: 40px; }
        h1 { color: #333; }
        h2 { margin-top: 30px; color: #444; }
        pre { background: #f4f4f4; padding: 10px; }
        ul { line-height: 1.6; }
    </style>
</head>
<body>
    <h1>Review Result</h1>

    <h2>Summary</h2>
    <p>{{ final_result.summary }}</p>

    <h2>Bugs</h2>
    <ul>{% for b in final_result.bugs %}<li>{{ b }}</li>{% endfor %}</ul>

    <h2>Style Issues</h2>
    <ul>{% for s in final_result.style_issues %}<li>{{ s }}</li>{% endfor %}</ul>

    <h2>Maintainability Issues</h2>
    <ul>{% for m in final_result.maintainability_issues %}<li>{{ m }}</li>{% endfor %}</ul>

    <h2>Documentation Issues</h2>
    <ul>{% for d in final_result.documentation_issues %}<li>{{ d }}</li>{% endfor %}</ul>

    <h2>Suggestions</h2>
    <ul>{% for s in final_result.suggestions %}<li>{{ s }}</li>{% endfor %}</ul>

    <h2>Improved Code</h2>
    <pre>{{ final_result.improved_code }}</pre>

    <h2>Scores</h2>
    <pre>{{ final_result.scores }}</pre>

    <h2>Overall Score</h2>
    <p>{{ final_result.overall_score }}</p>

    <br>
    <a href="/">Back</a>
</body>
</html>
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode - Home</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <div class="page-shell">
        <div class="hero-card">
            <div class="badge">LLM + Rule-based Review</div>
            <h1 class="page-title">PromptCode</h1>
            <p class="page-subtitle">
                Paste Python code, choose a review mode, and get structured feedback on bugs,
                style, maintainability, documentation, and improved code.
            </p>
        </div>

        <div class="main-card">
            <form action="/review" method="post" class="review-form">
                <label class="field-label" for="code">Python Code</label>
                <textarea
                    id="code"
                    name="code"
                    class="code-input"
                    rows="18"
                    placeholder="Paste your Python code here..."
                    required
                ></textarea>

                <div class="form-row">
                    <div class="form-group">
                        <label class="field-label" for="mode">Review Mode</label>
                        <select id="mode" name="mode" class="select-input">
                            <option value="bug">Bug Review</option>
                            <option value="style_docs">Style & Docs Review</option>
                            <option value="full" selected>Full Review</option>
                        </select>
                    </div>

                    <div class="form-group tips-box">
                        <div class="tips-title">What this tool checks</div>
                        <ul class="tips-list">
                            <li>Syntax validation</li>
                            <li>Docstring detection</li>
                            <li>Weak naming detection</li>
                            <li>flake8 style checks</li>
                            <li>LLM review and suggestions</li>
                        </ul>
                    </div>
                </div>

                <button type="submit" class="primary-btn">Review Code</button>
            </form>
        </div>
    </div>
</body>
</html>
""")

# %%
with open("result.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode - Review Result</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <div class="page-shell">
        <div class="hero-card result-hero">
            <div class="badge">Structured Review Output</div>
            <h1 class="page-title">Review Result</h1>
            <p class="page-subtitle">
                AI-assisted code review with rule-based analysis signals.
            </p>
        </div>

        <div class="summary-card">
            <h2 class="section-title">Summary</h2>
            <p class="summary-text">{{ final_result.summary }}</p>
        </div>

        <div class="score-panel">
            <div class="score-card">
                <div class="score-label">Correctness</div>
                <div class="score-value">{{ final_result.scores.correctness }}</div>
            </div>
            <div class="score-card">
                <div class="score-label">Readability</div>
                <div class="score-value">{{ final_result.scores.readability }}</div>
            </div>
            <div class="score-card">
                <div class="score-label">Maintainability</div>
                <div class="score-value">{{ final_result.scores.maintainability }}</div>
            </div>
            <div class="score-card">
                <div class="score-label">Documentation</div>
                <div class="score-value">{{ final_result.scores.documentation_quality }}</div>
            </div>
            <div class="score-card overall-score">
                <div class="score-label">Overall Score</div>
                <div class="score-value">{{ final_result.overall_score }}</div>
            </div>
        </div>

        <div class="grid-two">
            <section class="content-card">
                <h2 class="section-title">Bugs</h2>
                <ul class="styled-list">
                    {% for b in final_result.bugs %}
                        <li>{{ b }}</li>
                    {% endfor %}
                </ul>
            </section>

            <section class="content-card">
                <h2 class="section-title">Style Issues</h2>
                <ul class="styled-list">
                    {% for s in final_result.style_issues %}
                        <li>{{ s }}</li>
                    {% endfor %}
                </ul>
            </section>

            <section class="content-card">
                <h2 class="section-title">Maintainability Issues</h2>
                <ul class="styled-list">
                    {% for m in final_result.maintainability_issues %}
                        <li>{{ m }}</li>
                    {% endfor %}
                </ul>
            </section>

            <section class="content-card">
                <h2 class="section-title">Documentation Issues</h2>
                <ul class="styled-list">
                    {% for d in final_result.documentation_issues %}
                        <li>{{ d }}</li>
                    {% endfor %}
                </ul>
            </section>
        </div>

        <section class="content-card">
            <h2 class="section-title">Suggestions</h2>
            <ul class="styled-list">
                {% for s in final_result.suggestions %}
                    <li>{{ s }}</li>
                {% endfor %}
            </ul>
        </section>

        <section class="content-card">
            <h2 class="section-title">Improved Code</h2>
            <pre class="code-block">{{ final_result.improved_code }}</pre>
        </section>

        <div class="actions-row">
            <a href="/" class="secondary-btn">Back to Home</a>
        </div>
    </div>
</body>
</html>
""")

# %%
import os

os.makedirs("static", exist_ok=True)

with open("static/style.css", "w", encoding="utf-8") as f:
    f.write("""* {
    box-sizing: border-box;
}

body {
    margin: 0;
    font-family: Inter, Arial, Helvetica, sans-serif;
    background: #f4f7fb;
    color: #1f2937;
}

.page-shell {
    max-width: 1100px;
    margin: 0 auto;
    padding: 36px 20px 48px;
}

.hero-card,
.main-card,
.summary-card,
.content-card,
.score-card {
    background: #ffffff;
    border-radius: 18px;
    box-shadow: 0 10px 30px rgba(15, 23, 42, 0.08);
    border: 1px solid #e5e7eb;
}

.hero-card {
    padding: 32px;
    margin-bottom: 24px;
    background: linear-gradient(135deg, #ffffff 0%, #eef4ff 100%);
}

.result-hero {
    margin-bottom: 20px;
}

.badge {
    display: inline-block;
    background: #dbeafe;
    color: #1d4ed8;
    font-size: 13px;
    font-weight: 700;
    padding: 8px 12px;
    border-radius: 999px;
    margin-bottom: 14px;
}

.page-title {
    margin: 0 0 10px;
    font-size: 42px;
    line-height: 1.1;
    color: #111827;
}

.page-subtitle {
    margin: 0;
    font-size: 17px;
    line-height: 1.7;
    color: #4b5563;
    max-width: 820px;
}

.main-card {
    padding: 28px;
}

.review-form {
    display: flex;
    flex-direction: column;
    gap: 18px;
}

.field-label {
    display: block;
    font-size: 15px;
    font-weight: 700;
    color: #374151;
    margin-bottom: 8px;
}

.code-input {
    width: 100%;
    min-height: 360px;
    resize: vertical;
    border: 1px solid #d1d5db;
    border-radius: 14px;
    padding: 16px;
    font-family: "SFMono-Regular", Consolas, Menlo, monospace;
    font-size: 14px;
    line-height: 1.6;
    background: #0f172a;
    color: #e5e7eb;
    outline: none;
}

.code-input:focus,
.select-input:focus {
    border-color: #2563eb;
    box-shadow: 0 0 0 4px rgba(37, 99, 235, 0.12);
}

.form-row {
    display: grid;
    grid-template-columns: 260px 1fr;
    gap: 18px;
    align-items: start;
}

.form-group {
    display: flex;
    flex-direction: column;
}

.select-input {
    width: 100%;
    border: 1px solid #d1d5db;
    border-radius: 12px;
    padding: 12px 14px;
    font-size: 15px;
    background: #fff;
    color: #111827;
    outline: none;
}

.tips-box {
    background: #f8fafc;
    border: 1px solid #e5e7eb;
    border-radius: 14px;
    padding: 16px;
}

.tips-title {
    font-size: 15px;
    font-weight: 700;
    margin-bottom: 10px;
    color: #111827;
}

.tips-list {
    margin: 0;
    padding-left: 18px;
    color: #4b5563;
    line-height: 1.7;
    font-size: 14px;
}

.primary-btn,
.secondary-btn {
    border: none;
    border-radius: 12px;
    padding: 14px 22px;
    font-size: 15px;
    font-weight: 700;
    cursor: pointer;
    text-decoration: none;
    display: inline-block;
    transition: all 0.2s ease;
}

.primary-btn {
    background: #2563eb;
    color: #ffffff;
    width: fit-content;
}

.primary-btn:hover {
    background: #1d4ed8;
    transform: translateY(-1px);
}

.secondary-btn {
    background: #111827;
    color: #ffffff;
}

.secondary-btn:hover {
    background: #0b1220;
}

.summary-card {
    padding: 24px;
    margin-bottom: 20px;
}

.summary-text {
    margin: 0;
    color: #374151;
    line-height: 1.8;
    font-size: 16px;
}

.section-title {
    margin: 0 0 14px;
    font-size: 20px;
    color: #111827;
}

.score-panel {
    display: grid;
    grid-template-columns: repeat(5, 1fr);
    gap: 16px;
    margin-bottom: 22px;
}

.score-card {
    padding: 20px;
    text-align: center;
}

.overall-score {
    background: linear-gradient(135deg, #eff6ff 0%, #dbeafe 100%);
}

.score-label {
    font-size: 14px;
    color: #6b7280;
    margin-bottom: 8px;
    font-weight: 600;
}

.score-value {
    font-size: 32px;
    font-weight: 800;
    color: #111827;
}

.grid-two {
    display: grid;
    grid-template-columns: 1fr 1fr;
    gap: 18px;
    margin-bottom: 18px;
}

.content-card {
    padding: 24px;
    margin-bottom: 18px;
}

.styled-list {
    margin: 0;
    padding-left: 22px;
    line-height: 1.8;
    color: #374151;
}

.code-block {
    background: #0f172a;
    color: #e5e7eb;
    padding: 18px;
    border-radius: 14px;
    overflow-x: auto;
    line-height: 1.6;
    font-size: 14px;
    border: 1px solid #1f2937;
}

.actions-row {
    margin-top: 10px;
}

@media (max-width: 900px) {
    .form-row {
        grid-template-columns: 1fr;
    }

    .score-panel {
        grid-template-columns: 1fr 1fr;
    }

    .grid-two {
        grid-template-columns: 1fr;
    }

    .page-title {
        font-size: 34px;
    }
}

@media (max-width: 640px) {
    .score-panel {
        grid-template-columns: 1fr;
    }

    .page-shell {
        padding: 20px 14px 36px;
    }

    .hero-card,
    .main-card,
    .summary-card,
    .content-card {
        padding: 18px;
    }

    .page-title {
        font-size: 28px;
    }
}
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <div class="app-shell">
        <header class="topbar">
            <div>
                <div class="eyebrow">LLM + Rule-based Review</div>
                <h1 class="main-title">PromptCode</h1>
                <p class="subtitle">
                    Review Python code for bugs, style, maintainability, documentation, and improved code.
                </p>
            </div>
        </header>

        {% if error %}
        <section class="alert-card">
            <strong>Error:</strong> {{ error }}
        </section>
        {% endif %}

        {% if has_result %}
        <section class="result-stack">
            <div class="result-header-card">
                <div class="section-badge">Latest Review</div>
                <h2>Analysis Output</h2>
                <p>Your latest review appears below. Edit the code and run again anytime.</p>
            </div>

            <div class="summary-card">
                <h3>Summary</h3>
                <p>{{ final_result.summary }}</p>
            </div>

            <div class="score-grid">
                <div class="score-card">
                    <span class="score-label">Correctness</span>
                    <span class="score-value">{{ final_result.scores.correctness }}</span>
                </div>
                <div class="score-card">
                    <span class="score-label">Readability</span>
                    <span class="score-value">{{ final_result.scores.readability }}</span>
                </div>
                <div class="score-card">
                    <span class="score-label">Maintainability</span>
                    <span class="score-value">{{ final_result.scores.maintainability }}</span>
                </div>
                <div class="score-card">
                    <span class="score-label">Documentation</span>
                    <span class="score-value">{{ final_result.scores.documentation_quality }}</span>
                </div>
                <div class="score-card overall">
                    <span class="score-label">Overall</span>
                    <span class="score-value">{{ final_result.overall_score }}</span>
                </div>
            </div>

            <div class="result-grid">
                <section class="panel">
                    <h3>Bugs</h3>
                    <ul class="clean-list">
                        {% for b in final_result.bugs %}
                            <li>{{ b }}</li>
                        {% endfor %}
                    </ul>
                </section>

                <section class="panel">
                    <h3>Style Issues</h3>
                    <ul class="clean-list">
                        {% for s in final_result.style_issues %}
                            <li>{{ s }}</li>
                        {% endfor %}
                    </ul>
                </section>

                <section class="panel">
                    <h3>Maintainability Issues</h3>
                    <ul class="clean-list">
                        {% for m in final_result.maintainability_issues %}
                            <li>{{ m }}</li>
                        {% endfor %}
                    </ul>
                </section>

                <section class="panel">
                    <h3>Documentation Issues</h3>
                    <ul class="clean-list">
                        {% for d in final_result.documentation_issues %}
                            <li>{{ d }}</li>
                        {% endfor %}
                    </ul>
                </section>
            </div>

            <section class="panel wide">
                <h3>Suggestions</h3>
                <ul class="clean-list">
                    {% for s in final_result.suggestions %}
                        <li>{{ s }}</li>
                    {% endfor %}
                </ul>
            </section>

            <section class="panel wide">
                <h3>Improved Code</h3>
                <pre class="code-block">{{ final_result.improved_code }}</pre>
            </section>
        </section>
        {% endif %}

        <section class="composer-card">
            <form action="/" method="post" class="composer-form">
                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="hint-chip">Python only</span>
                        <span class="hint-chip">JSON-structured review</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Paste your Python code here..."
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="footer-tip">
                        Checks syntax, docstrings, naming, flake8, and LLM suggestions.
                    </div>
                    <button type="submit" class="run-btn">Review Code</button>
                </div>
            </form>
        </section>
    </div>
</body>
</html>
""")

# %%
import os

os.makedirs("static", exist_ok=True)

with open("static/style.css", "w", encoding="utf-8") as f:
    f.write("""* {
    box-sizing: border-box;
}

:root {
    --bg: #0b1020;
    --bg-soft: #11182d;
    --card: #ffffff;
    --card-soft: #f8fafc;
    --text: #111827;
    --muted: #6b7280;
    --line: #e5e7eb;
    --blue: #2563eb;
    --blue-dark: #1d4ed8;
    --shadow: 0 12px 30px rgba(15, 23, 42, 0.12);
    --radius: 20px;
}

html, body {
    margin: 0;
    padding: 0;
    font-family: Inter, Arial, Helvetica, sans-serif;
    background:
        radial-gradient(circle at top left, #1d4ed8 0%, transparent 22%),
        radial-gradient(circle at top right, #7c3aed 0%, transparent 18%),
        linear-gradient(180deg, #0b1020 0%, #10172b 100%);
    color: var(--text);
}

.app-shell {
    max-width: 1100px;
    margin: 0 auto;
    padding: 28px 18px 42px;
}

.topbar {
    color: #ffffff;
    margin-bottom: 20px;
}

.eyebrow {
    display: inline-block;
    font-size: 13px;
    font-weight: 700;
    background: rgba(255,255,255,0.12);
    border: 1px solid rgba(255,255,255,0.16);
    padding: 8px 12px;
    border-radius: 999px;
    margin-bottom: 14px;
}

.main-title {
    font-size: 48px;
    margin: 0 0 10px;
    line-height: 1.05;
}

.subtitle {
    margin: 0;
    max-width: 760px;
    color: rgba(255,255,255,0.82);
    line-height: 1.7;
    font-size: 16px;
}

.alert-card,
.result-header-card,
.summary-card,
.panel,
.composer-card,
.score-card {
    background: var(--card);
    border: 1px solid rgba(255,255,255,0.08);
    border-radius: var(--radius);
    box-shadow: var(--shadow);
}

.alert-card {
    padding: 16px 18px;
    margin-bottom: 18px;
    background: #fff7ed;
    border-color: #fdba74;
    color: #9a3412;
}

.result-stack {
    margin-bottom: 22px;
}

.result-header-card {
    padding: 22px 24px;
    margin-bottom: 16px;
    background: linear-gradient(135deg, #ffffff 0%, #eef4ff 100%);
}

.result-header-card h2 {
    margin: 0 0 8px;
    font-size: 28px;
}

.result-header-card p {
    margin: 0;
    color: var(--muted);
    line-height: 1.7;
}

.section-badge {
    display: inline-block;
    padding: 7px 11px;
    border-radius: 999px;
    background: #dbeafe;
    color: #1d4ed8;
    font-size: 12px;
    font-weight: 800;
    margin-bottom: 10px;
}

.summary-card {
    padding: 22px 24px;
    margin-bottom: 16px;
}

.summary-card h3,
.panel h3 {
    margin: 0 0 12px;
    font-size: 22px;
}

.summary-card p {
    margin: 0;
    line-height: 1.8;
    color: #374151;
}

.score-grid {
    display: grid;
    grid-template-columns: repeat(5, 1fr);
    gap: 14px;
    margin-bottom: 16px;
}

.score-card {
    padding: 18px 16px;
    text-align: center;
    background: #ffffff;
}

.score-card.overall {
    background: linear-gradient(135deg, #eff6ff 0%, #dbeafe 100%);
}

.score-label {
    display: block;
    font-size: 13px;
    font-weight: 700;
    color: var(--muted);
    margin-bottom: 8px;
}

.score-value {
    font-size: 34px;
    font-weight: 800;
    color: #111827;
}

.result-grid {
    display: grid;
    grid-template-columns: 1fr 1fr;
    gap: 16px;
    margin-bottom: 16px;
}

.panel {
    padding: 22px 24px;
    background: #ffffff;
}

.panel.wide {
    margin-bottom: 16px;
}

.clean-list {
    margin: 0;
    padding-left: 22px;
    color: #374151;
    line-height: 1.8;
}

.code-block {
    margin: 0;
    background: #0f172a;
    color: #e5e7eb;
    padding: 18px;
    border-radius: 16px;
    font-family: "SFMono-Regular", Consolas, Menlo, monospace;
    font-size: 14px;
    line-height: 1.6;
    overflow-x: auto;
}

.composer-card {
    position: sticky;
    bottom: 18px;
    padding: 0;
    overflow: hidden;
    background: rgba(255,255,255,0.98);
    backdrop-filter: blur(10px);
}

.composer-form {
    display: flex;
    flex-direction: column;
}

.composer-toolbar {
    display: flex;
    justify-content: space-between;
    align-items: center;
    gap: 14px;
    padding: 14px 16px;
    border-bottom: 1px solid var(--line);
    background: #f8fafc;
}

.toolbar-left {
    display: flex;
    align-items: center;
    gap: 10px;
}

.toolbar-label {
    font-size: 14px;
    font-weight: 700;
    color: #374151;
}

.mode-select {
    border: 1px solid #cbd5e1;
    border-radius: 12px;
    padding: 10px 12px;
    font-size: 14px;
    background: #fff;
    color: #111827;
    outline: none;
}

.mode-select:focus {
    border-color: var(--blue);
    box-shadow: 0 0 0 4px rgba(37, 99, 235, 0.12);
}

.toolbar-right {
    display: flex;
    gap: 8px;
    flex-wrap: wrap;
}

.hint-chip {
    display: inline-block;
    padding: 7px 10px;
    border-radius: 999px;
    background: #e5e7eb;
    color: #374151;
    font-size: 12px;
    font-weight: 700;
}

.composer-textarea {
    width: 100%;
    min-height: 240px;
    resize: vertical;
    border: none;
    outline: none;
    padding: 18px;
    font-family: "SFMono-Regular", Consolas, Menlo, monospace;
    font-size: 14px;
    line-height: 1.7;
    background: #0f172a;
    color: #e5e7eb;
}

.composer-footer {
    display: flex;
    justify-content: space-between;
    align-items: center;
    gap: 12px;
    padding: 14px 16px 16px;
    border-top: 1px solid var(--line);
    background: #ffffff;
}

.footer-tip {
    color: var(--muted);
    font-size: 14px;
}

.run-btn {
    border: none;
    border-radius: 14px;
    padding: 13px 20px;
    background: var(--blue);
    color: #ffffff;
    font-size: 15px;
    font-weight: 800;
    cursor: pointer;
    transition: transform 0.15s ease, background 0.15s ease;
}

.run-btn:hover {
    background: var(--blue-dark);
    transform: translateY(-1px);
}

@media (max-width: 980px) {
    .score-grid {
        grid-template-columns: repeat(2, 1fr);
    }

    .result-grid {
        grid-template-columns: 1fr;
    }
}

@media (max-width: 640px) {
    .main-title {
        font-size: 34px;
    }

    .composer-toolbar,
    .composer-footer {
        flex-direction: column;
        align-items: stretch;
    }

    .toolbar-left,
    .toolbar-right {
        width: 100%;
    }

    .mode-select {
        width: 100%;
    }

    .score-grid {
        grid-template-columns: 1fr;
    }

    .app-shell {
        padding: 18px 12px 28px;
    }

    .result-header-card,
    .summary-card,
    .panel {
        padding: 18px;
    }
}
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>
    <link rel="stylesheet" href="{{ url_for('static', filename='style.css') }}">
</head>
<body>
    <div class="chat-app">
        <header class="app-header">
            <div class="header-left">
                <div class="eyebrow">LLM + Rule-based Review</div>
                <h1>PromptCode</h1>
                <p>Python code review workspace with persistent in-page chat history.</p>
            </div>

            <form method="post" action="/" class="clear-form">
                <input type="hidden" name="action" value="clear">
                <button type="submit" class="ghost-btn">Clear Current Session</button>
            </form>
        </header>

        {% if error %}
        <div class="error-banner">
            {{ error }}
        </div>
        {% endif %}

        <main class="chat-history" id="chat-history">
            {% if history|length == 0 %}
            <section class="welcome-card">
                <div class="welcome-badge">Start here</div>
                <h2>Ask your first review</h2>
                <p>
                    Paste Python code into the fixed input panel below. Each review will stay on this page
                    as a conversation thread, with your code shown above the AI response.
                </p>
            </section>
            {% endif %}

            {% for item in history %}
            <div class="chat-turn">
                <section class="user-card">
                    <div class="card-topline">
                        <span class="role-pill user-pill">You</span>
                        <span class="mode-pill">{{ item.mode }}</span>
                    </div>
                    <div class="card-title">Submitted Code</div>
                    <pre class="code-block user-code">{{ item.user_code }}</pre>
                </section>

                <section class="assistant-card">
                    <div class="card-topline">
                        <span class="role-pill assistant-pill">PromptCode</span>
                    </div>

                    <div class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary }}</p>
                    </div>

                    <div class="score-grid">
                        <div class="score-box">
                            <span class="score-label">Correctness</span>
                            <span class="score-value">{{ item.result.scores.correctness }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Readability</span>
                            <span class="score-value">{{ item.result.scores.readability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Maintainability</span>
                            <span class="score-value">{{ item.result.scores.maintainability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Documentation</span>
                            <span class="score-value">{{ item.result.scores.documentation_quality }}</span>
                        </div>
                        <div class="score-box overall-score">
                            <span class="score-label">Overall</span>
                            <span class="score-value">{{ item.result.overall_score }}</span>
                        </div>
                    </div>

                    <div class="analysis-grid">
                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                        </section>
                    </div>

                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                    </section>

                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        <pre class="code-block">{{ item.result.improved_code }}</pre>
                    </section>
                </section>
            </div>
            {% endfor %}
        </main>

        <section class="composer-shell">
            <form action="/" method="post" class="composer-form">
                <input type="hidden" name="action" value="review">

                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="chip">Python only</span>
                        <span class="chip">Same-page history</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Paste your Python code here and continue the conversation..."
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="composer-tip">
                        This input stays fixed at the bottom while you scroll through prior reviews.
                    </div>
                    <button type="submit" class="send-btn">Review Code</button>
                </div>
            </form>
        </section>
    </div>

    <script>
        window.addEventListener("load", function () {
            window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });
        });
    </script>
</body>
</html>
""")

# %%
import os
os.makedirs("static", exist_ok=True)

with open("static/style.css", "w", encoding="utf-8") as f:
    f.write("""* {
    box-sizing: border-box;
}

:root {
    --bg: #0b1020;
    --bg2: #11182d;
    --panel: #ffffff;
    --panel-soft: #f8fafc;
    --line: #e5e7eb;
    --text: #111827;
    --muted: #6b7280;
    --blue: #2563eb;
    --blue-dark: #1d4ed8;
    --green: #16a34a;
    --shadow: 0 16px 40px rgba(15, 23, 42, 0.14);
    --radius: 22px;
}

html, body {
    margin: 0;
    padding: 0;
    min-height: 100%;
    font-family: Inter, Arial, Helvetica, sans-serif;
    color: var(--text);
    background:
        radial-gradient(circle at top left, rgba(37,99,235,0.25) 0%, transparent 24%),
        radial-gradient(circle at top right, rgba(124,58,237,0.18) 0%, transparent 20%),
        linear-gradient(180deg, #0b1020 0%, #10172b 100%);
}

body {
    padding-bottom: 360px;
}

.chat-app {
    max-width: 1100px;
    margin: 0 auto;
    padding: 28px 18px 40px;
}

.app-header {
    display: flex;
    justify-content: space-between;
    align-items: flex-start;
    gap: 16px;
    color: #ffffff;
    margin-bottom: 22px;
}

.eyebrow {
    display: inline-block;
    padding: 8px 12px;
    border-radius: 999px;
    background: rgba(255,255,255,0.12);
    border: 1px solid rgba(255,255,255,0.14);
    font-size: 12px;
    font-weight: 800;
    margin-bottom: 14px;
}

.app-header h1 {
    margin: 0 0 10px;
    font-size: 46px;
    line-height: 1.05;
}

.app-header p {
    margin: 0;
    max-width: 720px;
    line-height: 1.7;
    color: rgba(255,255,255,0.82);
}

.ghost-btn {
    border: 1px solid rgba(255,255,255,0.18);
    background: rgba(255,255,255,0.10);
    color: #ffffff;
    padding: 12px 14px;
    border-radius: 14px;
    font-weight: 700;
    cursor: pointer;
}

.ghost-btn:hover {
    background: rgba(255,255,255,0.16);
}

.error-banner {
    background: #fff7ed;
    color: #9a3412;
    border: 1px solid #fdba74;
    border-radius: 16px;
    padding: 14px 16px;
    margin-bottom: 18px;
    box-shadow: var(--shadow);
}

.chat-history {
    display: flex;
    flex-direction: column;
    gap: 18px;
}

.welcome-card,
.user-card,
.assistant-card {
    background: var(--panel);
    border: 1px solid rgba(255,255,255,0.08);
    border-radius: var(--radius);
    box-shadow: var(--shadow);
}

.welcome-card {
    padding: 26px;
    background: linear-gradient(135deg, #ffffff 0%, #eef4ff 100%);
}

.welcome-badge {
    display: inline-block;
    background: #dbeafe;
    color: #1d4ed8;
    padding: 8px 12px;
    border-radius: 999px;
    font-size: 12px;
    font-weight: 800;
    margin-bottom: 12px;
}

.welcome-card h2 {
    margin: 0 0 10px;
    font-size: 28px;
}

.welcome-card p {
    margin: 0;
    color: #4b5563;
    line-height: 1.8;
}

.chat-turn {
    display: flex;
    flex-direction: column;
    gap: 12px;
}

.user-card {
    padding: 20px 22px;
    background: linear-gradient(135deg, #eff6ff 0%, #dbeafe 100%);
}

.assistant-card {
    padding: 22px 24px;
    background: #ffffff;
}

.card-topline {
    display: flex;
    align-items: center;
    gap: 10px;
    margin-bottom: 12px;
    flex-wrap: wrap;
}

.role-pill,
.mode-pill {
    display: inline-block;
    padding: 7px 11px;
    border-radius: 999px;
    font-size: 12px;
    font-weight: 800;
}

.user-pill {
    background: #bfdbfe;
    color: #1d4ed8;
}

.assistant-pill {
    background: #dcfce7;
    color: #166534;
}

.mode-pill {
    background: #e5e7eb;
    color: #374151;
}

.card-title {
    font-size: 18px;
    font-weight: 800;
    margin-bottom: 12px;
}

.summary-box,
.wide-panel,
.mini-panel {
    background: #f8fafc;
    border: 1px solid var(--line);
    border-radius: 18px;
    padding: 18px;
}

.summary-box {
    margin-bottom: 14px;
}

.summary-box h3,
.mini-panel h3,
.wide-panel h3 {
    margin: 0 0 10px;
    font-size: 20px;
}

.summary-box p {
    margin: 0;
    line-height: 1.8;
    color: #374151;
}

.score-grid {
    display: grid;
    grid-template-columns: repeat(5, 1fr);
    gap: 12px;
    margin-bottom: 14px;
}

.score-box {
    background: #ffffff;
    border: 1px solid var(--line);
    border-radius: 18px;
    padding: 16px;
    text-align: center;
}

.score-box.overall-score {
    background: linear-gradient(135deg, #eff6ff 0%, #dbeafe 100%);
}

.score-label {
    display: block;
    font-size: 13px;
    font-weight: 700;
    color: var(--muted);
    margin-bottom: 8px;
}

.score-value {
    font-size: 30px;
    font-weight: 800;
    color: #111827;
}

.analysis-grid {
    display: grid;
    grid-template-columns: 1fr 1fr;
    gap: 12px;
    margin-bottom: 14px;
}

.clean-list {
    margin: 0;
    padding-left: 20px;
    color: #374151;
    line-height: 1.8;
}

.code-block {
    margin: 0;
    background: #0f172a;
    color: #e5e7eb;
    border-radius: 16px;
    padding: 16px;
    overflow-x: auto;
    font-family: "SFMono-Regular", Consolas, Menlo, monospace;
    font-size: 14px;
    line-height: 1.6;
}

.user-code {
    background: rgba(15,23,42,0.95);
}

.composer-shell {
    position: fixed;
    left: 50%;
    transform: translateX(-50%);
    bottom: 16px;
    width: min(1100px, calc(100vw - 24px));
    z-index: 50;
    background: rgba(255,255,255,0.96);
    backdrop-filter: blur(12px);
    border: 1px solid rgba(255,255,255,0.18);
    border-radius: 24px;
    box-shadow: 0 20px 50px rgba(15, 23, 42, 0.28);
    overflow: hidden;
}

.composer-form {
    display: flex;
    flex-direction: column;
}

.composer-toolbar {
    display: flex;
    justify-content: space-between;
    align-items: center;
    gap: 12px;
    padding: 14px 16px;
    border-bottom: 1px solid var(--line);
    background: #f8fafc;
}

.toolbar-left {
    display: flex;
    align-items: center;
    gap: 10px;
}

.toolbar-label {
    font-size: 14px;
    font-weight: 800;
    color: #374151;
}

.mode-select {
    border: 1px solid #cbd5e1;
    border-radius: 12px;
    padding: 10px 12px;
    font-size: 14px;
    background: #ffffff;
    color: #111827;
    outline: none;
}

.mode-select:focus {
    border-color: var(--blue);
    box-shadow: 0 0 0 4px rgba(37, 99, 235, 0.12);
}

.toolbar-right {
    display: flex;
    gap: 8px;
    flex-wrap: wrap;
}

.chip {
    display: inline-block;
    padding: 7px 10px;
    border-radius: 999px;
    background: #e5e7eb;
    color: #374151;
    font-size: 12px;
    font-weight: 800;
}

.composer-textarea {
    width: 100%;
    min-height: 190px;
    max-height: 320px;
    resize: vertical;
    border: none;
    outline: none;
    padding: 18px;
    background: #0f172a;
    color: #e5e7eb;
    font-family: "SFMono-Regular", Consolas, Menlo, monospace;
    font-size: 14px;
    line-height: 1.7;
}

.composer-footer {
    display: flex;
    justify-content: space-between;
    align-items: center;
    gap: 12px;
    padding: 14px 16px 16px;
    border-top: 1px solid var(--line);
    background: #ffffff;
}

.composer-tip {
    color: var(--muted);
    font-size: 14px;
}

.send-btn {
    border: none;
    border-radius: 14px;
    padding: 13px 20px;
    background: var(--blue);
    color: #ffffff;
    font-size: 15px;
    font-weight: 800;
    cursor: pointer;
}

.send-btn:hover {
    background: var(--blue-dark);
}

@media (max-width: 980px) {
    .score-grid {
        grid-template-columns: repeat(2, 1fr);
    }

    .analysis-grid {
        grid-template-columns: 1fr;
    }

    .app-header {
        flex-direction: column;
    }
}

@media (max-width: 640px) {
    body {
        padding-bottom: 420px;
    }

    .app-header h1 {
        font-size: 34px;
    }

    .composer-toolbar,
    .composer-footer {
        flex-direction: column;
        align-items: stretch;
    }

    .toolbar-left,
    .toolbar-right {
        width: 100%;
    }

    .mode-select {
        width: 100%;
    }

    .score-grid {
        grid-template-columns: 1fr;
    }

    .chat-app {
        padding: 18px 12px 32px;
    }

    .user-card,
    .assistant-card,
    .welcome-card {
        padding: 18px;
    }

    .composer-shell {
        width: calc(100vw - 16px);
        bottom: 8px;
    }
}
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>
    <style>
        * { box-sizing: border-box; }

        :root {
            --bg: #f7f7fb;
            --panel: #ffffff;
            --line: #e5e7eb;
            --text: #111827;
            --muted: #6b7280;
            --blue: #2563eb;
            --blue-dark: #1d4ed8;
            --shadow: 0 10px 30px rgba(15, 23, 42, 0.10);
            --radius: 18px;
        }

        html, body {
            margin: 0;
            padding: 0;
            background: var(--bg);
            color: var(--text);
            font-family: Arial, Helvetica, sans-serif;
        }

        body {
            padding-bottom: 340px; /* 给底部固定输入框留空间 */
        }

        .page {
            max-width: 1000px;
            margin: 0 auto;
            padding: 28px 18px 24px;
        }

        .topbar {
            margin-bottom: 22px;
        }

        .eyebrow {
            display: inline-block;
            background: #dbeafe;
            color: #1d4ed8;
            padding: 8px 12px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
            margin-bottom: 12px;
        }

        h1 {
            font-size: 44px;
            margin: 0 0 10px;
        }

        .subtitle {
            margin: 0;
            color: var(--muted);
            line-height: 1.7;
            max-width: 760px;
        }

        .clear-row {
            margin-top: 14px;
        }

        .ghost-btn {
            border: 1px solid var(--line);
            background: white;
            color: #374151;
            padding: 10px 14px;
            border-radius: 12px;
            font-weight: 700;
            cursor: pointer;
        }

        .ghost-btn:hover {
            background: #f3f4f6;
        }

        .error-banner {
            background: #fff7ed;
            border: 1px solid #fdba74;
            color: #9a3412;
            padding: 14px 16px;
            border-radius: 14px;
            margin-bottom: 16px;
        }

        .history {
            display: flex;
            flex-direction: column;
            gap: 18px;
        }

        .welcome-card,
        .user-card,
        .assistant-card,
        .mini-panel,
        .summary-box,
        .wide-panel,
        .score-box {
            background: var(--panel);
            border: 1px solid var(--line);
            border-radius: var(--radius);
            box-shadow: var(--shadow);
        }

        .welcome-card {
            padding: 24px;
        }

        .welcome-card h2 {
            margin: 0 0 10px;
        }

        .welcome-card p {
            margin: 0;
            color: var(--muted);
            line-height: 1.8;
        }

        .turn {
            display: flex;
            flex-direction: column;
            gap: 12px;
        }

        .user-card {
            padding: 20px;
            background: #eef4ff;
        }

        .assistant-card {
            padding: 20px;
        }

        .card-top {
            display: flex;
            gap: 8px;
            align-items: center;
            margin-bottom: 10px;
            flex-wrap: wrap;
        }

        .pill {
            display: inline-block;
            padding: 6px 10px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
        }

        .pill-user {
            background: #bfdbfe;
            color: #1d4ed8;
        }

        .pill-assistant {
            background: #dcfce7;
            color: #166534;
        }

        .pill-mode {
            background: #e5e7eb;
            color: #374151;
        }

        .section-title {
            margin: 0 0 10px;
            font-size: 20px;
        }

        .code-block {
            margin: 0;
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.6;
            white-space: pre-wrap;
        }

        .summary-box,
        .wide-panel {
            padding: 16px;
            margin-bottom: 12px;
            background: #f8fafc;
        }

        .summary-box p {
            margin: 0;
            line-height: 1.8;
            color: #374151;
        }

        .score-grid {
            display: grid;
            grid-template-columns: repeat(5, 1fr);
            gap: 10px;
            margin-bottom: 12px;
        }

        .score-box {
            padding: 16px;
            text-align: center;
        }

        .score-label {
            display: block;
            font-size: 13px;
            color: var(--muted);
            margin-bottom: 8px;
            font-weight: 700;
        }

        .score-value {
            font-size: 28px;
            font-weight: 800;
        }

        .analysis-grid {
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 12px;
            margin-bottom: 12px;
        }

        .mini-panel {
            padding: 16px;
            background: #f8fafc;
        }

        .mini-panel h3,
        .wide-panel h3 {
            margin: 0 0 10px;
            font-size: 18px;
        }

        .clean-list {
            margin: 0;
            padding-left: 20px;
            line-height: 1.8;
            color: #374151;
        }

        /* 底部固定输入框 */
        .composer-wrap {
            position: fixed;
            left: 50%;
            transform: translateX(-50%);
            bottom: 16px;
            width: min(1000px, calc(100vw - 24px));
            z-index: 9999;
        }

        .composer {
            background: rgba(255,255,255,0.98);
            border: 1px solid var(--line);
            border-radius: 22px;
            box-shadow: 0 20px 50px rgba(15, 23, 42, 0.18);
            overflow: hidden;
            backdrop-filter: blur(10px);
        }

        .composer-toolbar {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-bottom: 1px solid var(--line);
            background: #f8fafc;
        }

        .toolbar-left {
            display: flex;
            align-items: center;
            gap: 10px;
        }

        .toolbar-label {
            font-size: 14px;
            font-weight: 700;
            color: #374151;
        }

        .mode-select {
            border: 1px solid #cbd5e1;
            border-radius: 12px;
            padding: 10px 12px;
            background: white;
            font-size: 14px;
            outline: none;
        }

        .mode-select:focus {
            border-color: var(--blue);
            box-shadow: 0 0 0 4px rgba(37,99,235,0.12);
        }

        .toolbar-right {
            display: flex;
            gap: 8px;
            flex-wrap: wrap;
        }

        .chip {
            display: inline-block;
            padding: 7px 10px;
            border-radius: 999px;
            background: #e5e7eb;
            color: #374151;
            font-size: 12px;
            font-weight: 700;
        }

        .composer-textarea {
            width: 100%;
            min-height: 180px;
            max-height: 320px;
            resize: vertical;
            border: none;
            outline: none;
            padding: 18px;
            background: #0f172a;
            color: #e5e7eb;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.7;
        }

        .composer-footer {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-top: 1px solid var(--line);
            background: white;
        }

        .composer-tip {
            color: var(--muted);
            font-size: 14px;
        }

        .send-btn {
            border: none;
            background: var(--blue);
            color: white;
            padding: 13px 20px;
            border-radius: 14px;
            font-size: 15px;
            font-weight: 800;
            cursor: pointer;
        }

        .send-btn:hover {
            background: var(--blue-dark);
        }

        @media (max-width: 900px) {
            .score-grid {
                grid-template-columns: repeat(2, 1fr);
            }

            .analysis-grid {
                grid-template-columns: 1fr;
            }
        }

        @media (max-width: 640px) {
            body {
                padding-bottom: 430px;
            }

            h1 {
                font-size: 32px;
            }

            .composer-toolbar,
            .composer-footer {
                flex-direction: column;
                align-items: stretch;
            }

            .toolbar-left,
            .toolbar-right {
                width: 100%;
            }

            .mode-select {
                width: 100%;
            }

            .score-grid {
                grid-template-columns: 1fr;
            }

            .composer-wrap {
                width: calc(100vw - 16px);
                bottom: 8px;
            }
        }
    </style>
</head>
<body>
    <div class="page">
        <header class="topbar">
            <div class="eyebrow">LLM + Rule-based Review</div>
            <h1>PromptCode</h1>
            <p class="subtitle">
                Python code review workspace with persistent in-page chat history.
            </p>

            <div class="clear-row">
                <form method="post" action="/">
                    <input type="hidden" name="action" value="clear">
                    <button type="submit" class="ghost-btn">Clear Current Session</button>
                </form>
            </div>
        </header>

        {% if error %}
        <div class="error-banner">{{ error }}</div>
        {% endif %}

        <main class="history" id="history">
            {% if history|length == 0 %}
            <section class="welcome-card">
                <h2>Start your first review</h2>
                <p>
                    Your submitted code will appear above each answer, and the input box will stay fixed at the bottom like a chat composer.
                </p>
            </section>
            {% endif %}

            {% for item in history %}
            <div class="turn">
                <section class="user-card">
                    <div class="card-top">
                        <span class="pill pill-user">You</span>
                        <span class="pill pill-mode">{{ item.mode }}</span>
                    </div>
                    <div class="section-title">Submitted Code</div>
                    <pre class="code-block">{{ item.user_code }}</pre>
                </section>

                <section class="assistant-card">
                    <div class="card-top">
                        <span class="pill pill-assistant">PromptCode</span>
                    </div>

                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary }}</p>
                    </section>

                    <div class="score-grid">
                        <div class="score-box">
                            <span class="score-label">Correctness</span>
                            <span class="score-value">{{ item.result.scores.correctness }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Readability</span>
                            <span class="score-value">{{ item.result.scores.readability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Maintainability</span>
                            <span class="score-value">{{ item.result.scores.maintainability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Documentation</span>
                            <span class="score-value">{{ item.result.scores.documentation_quality }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Overall</span>
                            <span class="score-value">{{ item.result.overall_score }}</span>
                        </div>
                    </div>

                    <div class="analysis-grid">
                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                        </section>
                    </div>

                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                    </section>

                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        <pre class="code-block">{{ item.result.improved_code }}</pre>
                    </section>
                </section>
            </div>
            {% endfor %}
        </main>
    </div>

    <div class="composer-wrap">
        <section class="composer">
            <form action="/" method="post">
                <input type="hidden" name="action" value="review">

                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="chip">Python only</span>
                        <span class="chip">Fixed bottom input</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Paste your Python code here and continue asking..."
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="composer-tip">The composer stays visible while you scroll through previous reviews.</div>
                    <button type="submit" class="send-btn">Review Code</button>
                </div>
            </form>
        </section>
    </div>

    <script>
        window.addEventListener("load", function () {
            window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });
        });
    </script>
</body>
</html>
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>
    <style>
        * { box-sizing: border-box; }

        :root {
            --bg: #f7f7fb;
            --panel: #ffffff;
            --line: #e5e7eb;
            --text: #111827;
            --muted: #6b7280;
            --blue: #2563eb;
            --blue-dark: #1d4ed8;
            --shadow: 0 10px 30px rgba(15, 23, 42, 0.10);
            --radius: 18px;
        }

        html, body {
            margin: 0;
            padding: 0;
            background: var(--bg);
            color: var(--text);
            font-family: Arial, Helvetica, sans-serif;
        }

        body {
            padding-bottom: 260px;
        }

        .page {
            max-width: 1000px;
            margin: 0 auto;
            padding: 28px 18px 24px;
        }

        .topbar {
            margin-bottom: 22px;
        }

        .eyebrow {
            display: inline-block;
            background: #dbeafe;
            color: #1d4ed8;
            padding: 8px 12px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
            margin-bottom: 12px;
        }

        h1 {
            font-size: 44px;
            margin: 0 0 10px;
        }

        .subtitle {
            margin: 0;
            color: var(--muted);
            line-height: 1.7;
            max-width: 760px;
        }

        .clear-row {
            margin-top: 14px;
        }

        .ghost-btn {
            border: 1px solid var(--line);
            background: white;
            color: #374151;
            padding: 10px 14px;
            border-radius: 12px;
            font-weight: 700;
            cursor: pointer;
        }

        .ghost-btn:hover {
            background: #f3f4f6;
        }

        .error-banner {
            background: #fff7ed;
            border: 1px solid #fdba74;
            color: #9a3412;
            padding: 14px 16px;
            border-radius: 14px;
            margin-bottom: 16px;
        }

        .history {
            display: flex;
            flex-direction: column;
            gap: 18px;
        }

        .welcome-card,
        .user-card,
        .assistant-card,
        .mini-panel,
        .summary-box,
        .wide-panel,
        .score-box {
            background: var(--panel);
            border: 1px solid var(--line);
            border-radius: var(--radius);
            box-shadow: var(--shadow);
        }

        .welcome-card {
            padding: 24px;
        }

        .welcome-card h2 {
            margin: 0 0 10px;
        }

        .welcome-card p {
            margin: 0;
            color: var(--muted);
            line-height: 1.8;
        }

        .turn {
            display: flex;
            flex-direction: column;
            gap: 12px;
        }

        .user-card {
            padding: 20px;
            background: #eef4ff;
        }

        .assistant-card {
            padding: 20px;
        }

        .card-top {
            display: flex;
            gap: 8px;
            align-items: center;
            margin-bottom: 10px;
            flex-wrap: wrap;
        }

        .pill {
            display: inline-block;
            padding: 6px 10px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
        }

        .pill-user {
            background: #bfdbfe;
            color: #1d4ed8;
        }

        .pill-assistant {
            background: #dcfce7;
            color: #166534;
        }

        .pill-mode {
            background: #e5e7eb;
            color: #374151;
        }

        .section-title {
            margin: 0 0 10px;
            font-size: 20px;
        }

        .code-block {
            margin: 0;
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.6;
            white-space: pre-wrap;
        }

        .summary-box,
        .wide-panel {
            padding: 16px;
            margin-bottom: 12px;
            background: #f8fafc;
        }

        .summary-box p {
            margin: 0;
            line-height: 1.8;
            color: #374151;
        }

        .score-grid {
            display: grid;
            grid-template-columns: repeat(5, 1fr);
            gap: 10px;
            margin-bottom: 12px;
        }

        .score-box {
            padding: 16px;
            text-align: center;
        }

        .score-label {
            display: block;
            font-size: 13px;
            color: var(--muted);
            margin-bottom: 8px;
            font-weight: 700;
        }

        .score-value {
            font-size: 28px;
            font-weight: 800;
        }

        .analysis-grid {
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 12px;
            margin-bottom: 12px;
        }

        .mini-panel {
            padding: 16px;
            background: #f8fafc;
        }

        .mini-panel h3,
        .wide-panel h3 {
            margin: 0 0 10px;
            font-size: 18px;
        }

        .clean-list {
            margin: 0;
            padding-left: 20px;
            line-height: 1.8;
            color: #374151;
        }

        .composer-wrap {
            position: fixed;
            left: 50%;
            transform: translateX(-50%);
            bottom: 16px;
            width: min(1000px, calc(100vw - 24px));
            z-index: 9999;
        }

        .composer {
            background: rgba(255,255,255,0.98);
            border: 1px solid var(--line);
            border-radius: 22px;
            box-shadow: 0 20px 50px rgba(15, 23, 42, 0.18);
            overflow: hidden;
            backdrop-filter: blur(10px);
        }

        .composer-toolbar {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-bottom: 1px solid var(--line);
            background: #f8fafc;
        }

        .toolbar-left {
            display: flex;
            align-items: center;
            gap: 10px;
        }

        .toolbar-label {
            font-size: 14px;
            font-weight: 700;
            color: #374151;
        }

        .mode-select {
            border: 1px solid #cbd5e1;
            border-radius: 12px;
            padding: 10px 12px;
            background: white;
            font-size: 14px;
            outline: none;
        }

        .mode-select:focus {
            border-color: var(--blue);
            box-shadow: 0 0 0 4px rgba(37,99,235,0.12);
        }

        .toolbar-right {
            display: flex;
            gap: 8px;
            flex-wrap: wrap;
        }

        .chip {
            display: inline-block;
            padding: 7px 10px;
            border-radius: 999px;
            background: #e5e7eb;
            color: #374151;
            font-size: 12px;
            font-weight: 700;
        }

        .composer-textarea {
            width: 100%;
            min-height: 90px;
            height: 90px;
            max-height: 260px;
            resize: none;
            overflow-y: auto;
            border: none;
            outline: none;
            padding: 18px;
            background: #0f172a;
            color: #e5e7eb;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.7;
        }

        .composer-footer {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-top: 1px solid var(--line);
            background: white;
        }

        .composer-tip {
            color: var(--muted);
            font-size: 14px;
        }

        .send-btn {
            border: none;
            background: var(--blue);
            color: white;
            padding: 13px 20px;
            border-radius: 14px;
            font-size: 15px;
            font-weight: 800;
            cursor: pointer;
        }

        .send-btn:hover {
            background: var(--blue-dark);
        }

        @media (max-width: 900px) {
            .score-grid {
                grid-template-columns: repeat(2, 1fr);
            }

            .analysis-grid {
                grid-template-columns: 1fr;
            }
        }

        @media (max-width: 640px) {
            body {
                padding-bottom: 330px;
            }

            h1 {
                font-size: 32px;
            }

            .composer-toolbar,
            .composer-footer {
                flex-direction: column;
                align-items: stretch;
            }

            .toolbar-left,
            .toolbar-right {
                width: 100%;
            }

            .mode-select {
                width: 100%;
            }

            .score-grid {
                grid-template-columns: 1fr;
            }

            .composer-wrap {
                width: calc(100vw - 16px);
                bottom: 8px;
            }

            .composer-textarea {
                min-height: 78px;
                height: 78px;
                max-height: 220px;
            }
        }
    </style>
</head>
<body>
    <div class="page">
        <header class="topbar">
            <div class="eyebrow">LLM + Rule-based Review</div>
            <h1>PromptCode</h1>
            <p class="subtitle">
                Python code review workspace with persistent in-page chat history.
            </p>

            <div class="clear-row">
                <form method="post" action="/">
                    <input type="hidden" name="action" value="clear">
                    <button type="submit" class="ghost-btn">Clear Current Session</button>
                </form>
            </div>
        </header>

        {% if error %}
        <div class="error-banner">{{ error }}</div>
        {% endif %}

        <main class="history" id="history">
            {% if history|length == 0 %}
            <section class="welcome-card">
                <h2>Start your first review</h2>
                <p>
                    Your submitted code will appear above each answer, and the input box will stay fixed at the bottom like a chat composer.
                </p>
            </section>
            {% endif %}

            {% for item in history %}
            <div class="turn">
                <section class="user-card">
                    <div class="card-top">
                        <span class="pill pill-user">You</span>
                        <span class="pill pill-mode">{{ item.mode }}</span>
                    </div>
                    <div class="section-title">Submitted Code</div>
                    <pre class="code-block">{{ item.user_code }}</pre>
                </section>

                <section class="assistant-card">
                    <div class="card-top">
                        <span class="pill pill-assistant">PromptCode</span>
                    </div>

                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary }}</p>
                    </section>

                    <div class="score-grid">
                        <div class="score-box">
                            <span class="score-label">Correctness</span>
                            <span class="score-value">{{ item.result.scores.correctness }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Readability</span>
                            <span class="score-value">{{ item.result.scores.readability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Maintainability</span>
                            <span class="score-value">{{ item.result.scores.maintainability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Documentation</span>
                            <span class="score-value">{{ item.result.scores.documentation_quality }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Overall</span>
                            <span class="score-value">{{ item.result.overall_score }}</span>
                        </div>
                    </div>

                    <div class="analysis-grid">
                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                        </section>
                    </div>

                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                    </section>

                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        <pre class="code-block">{{ item.result.improved_code }}</pre>
                    </section>
                </section>
            </div>
            {% endfor %}
        </main>
    </div>

    <div class="composer-wrap">
        <section class="composer">
            <form action="/" method="post">
                <input type="hidden" name="action" value="review">

                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="chip">Python only</span>
                        <span class="chip">Fixed bottom input</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Paste your Python code here and continue asking..."
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="composer-tip">The composer stays visible while you scroll through previous reviews.</div>
                    <button type="submit" class="send-btn">Review Code</button>
                </div>
            </form>
        </section>
    </div>

    <script>
        const textarea = document.getElementById("code");

        function autoResize(el) {
            el.style.height = "90px";
            const next = Math.min(el.scrollHeight, 260);
            el.style.height = next + "px";
        }

        window.addEventListener("load", function () {
            autoResize(textarea);
            window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });
        });

        textarea.addEventListener("input", function () {
            autoResize(textarea);
        });
    </script>
</body>
</html>
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>
    <style>
        * { box-sizing: border-box; }

        :root {
            --bg: #f7f7fb;
            --panel: #ffffff;
            --line: #e5e7eb;
            --text: #111827;
            --muted: #6b7280;
            --blue: #2563eb;
            --blue-dark: #1d4ed8;
            --shadow: 0 10px 30px rgba(15, 23, 42, 0.10);
            --radius: 18px;
        }

        html, body {
            margin: 0;
            padding: 0;
            background: var(--bg);
            color: var(--text);
            font-family: Arial, Helvetica, sans-serif;
        }

        body {
            padding-bottom: 260px;
        }

        .page {
            max-width: 1000px;
            margin: 0 auto;
            padding: 28px 18px 24px;
        }

        .topbar {
            margin-bottom: 22px;
        }

        .eyebrow {
            display: inline-block;
            background: #dbeafe;
            color: #1d4ed8;
            padding: 8px 12px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
            margin-bottom: 12px;
        }

        h1 {
            font-size: 44px;
            margin: 0 0 10px;
        }

        .subtitle {
            margin: 0;
            color: var(--muted);
            line-height: 1.7;
            max-width: 760px;
        }

        .clear-row {
            margin-top: 14px;
        }

        .ghost-btn {
            border: 1px solid var(--line);
            background: white;
            color: #374151;
            padding: 10px 14px;
            border-radius: 12px;
            font-weight: 700;
            cursor: pointer;
        }

        .ghost-btn:hover {
            background: #f3f4f6;
        }

        .error-banner {
            background: #fff7ed;
            border: 1px solid #fdba74;
            color: #9a3412;
            padding: 14px 16px;
            border-radius: 14px;
            margin-bottom: 16px;
        }

        .history {
            display: flex;
            flex-direction: column;
            gap: 18px;
        }

        .welcome-card,
        .user-card,
        .assistant-card,
        .mini-panel,
        .summary-box,
        .wide-panel,
        .score-box {
            background: var(--panel);
            border: 1px solid var(--line);
            border-radius: var(--radius);
            box-shadow: var(--shadow);
        }

        .welcome-card {
            padding: 24px;
        }

        .welcome-card h2 {
            margin: 0 0 10px;
        }

        .welcome-card p {
            margin: 0;
            color: var(--muted);
            line-height: 1.8;
        }

        .turn {
            display: flex;
            flex-direction: column;
            gap: 12px;
        }

        .user-card {
            padding: 20px;
            background: #eef4ff;
        }

        .assistant-card {
            padding: 20px;
        }

        .card-top {
            display: flex;
            gap: 8px;
            align-items: center;
            margin-bottom: 10px;
            flex-wrap: wrap;
        }

        .pill {
            display: inline-block;
            padding: 6px 10px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
        }

        .pill-user {
            background: #bfdbfe;
            color: #1d4ed8;
        }

        .pill-assistant {
            background: #dcfce7;
            color: #166534;
        }

        .pill-mode {
            background: #e5e7eb;
            color: #374151;
        }

        .section-title {
            margin: 0 0 10px;
            font-size: 20px;
        }

        .code-block {
            margin: 0;
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.6;
            white-space: pre-wrap;
        }

        .summary-box,
        .wide-panel {
            padding: 16px;
            margin-bottom: 12px;
            background: #f8fafc;
        }

        .summary-box p {
            margin: 0;
            line-height: 1.8;
            color: #374151;
            white-space: pre-wrap;
        }

        .score-grid {
            display: grid;
            grid-template-columns: repeat(5, 1fr);
            gap: 10px;
            margin-bottom: 12px;
        }

        .score-box {
            padding: 16px;
            text-align: center;
        }

        .score-label {
            display: block;
            font-size: 13px;
            color: var(--muted);
            margin-bottom: 8px;
            font-weight: 700;
        }

        .score-value {
            font-size: 28px;
            font-weight: 800;
        }

        .analysis-grid {
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 12px;
            margin-bottom: 12px;
        }

        .mini-panel {
            padding: 16px;
            background: #f8fafc;
        }

        .mini-panel h3,
        .wide-panel h3 {
            margin: 0 0 10px;
            font-size: 18px;
        }

        .clean-list {
            margin: 0;
            padding-left: 20px;
            line-height: 1.8;
            color: #374151;
        }

        .composer-wrap {
            position: fixed;
            left: 50%;
            transform: translateX(-50%);
            bottom: 16px;
            width: min(1000px, calc(100vw - 24px));
            z-index: 9999;
        }

        .composer {
            background: rgba(255,255,255,0.98);
            border: 1px solid var(--line);
            border-radius: 22px;
            box-shadow: 0 20px 50px rgba(15, 23, 42, 0.18);
            overflow: hidden;
            backdrop-filter: blur(10px);
        }

        .composer-toolbar {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-bottom: 1px solid var(--line);
            background: #f8fafc;
        }

        .toolbar-left {
            display: flex;
            align-items: center;
            gap: 10px;
        }

        .toolbar-label {
            font-size: 14px;
            font-weight: 700;
            color: #374151;
        }

        .mode-select {
            border: 1px solid #cbd5e1;
            border-radius: 12px;
            padding: 10px 12px;
            background: white;
            font-size: 14px;
            outline: none;
        }

        .mode-select:focus {
            border-color: var(--blue);
            box-shadow: 0 0 0 4px rgba(37,99,235,0.12);
        }

        .toolbar-right {
            display: flex;
            gap: 8px;
            flex-wrap: wrap;
        }

        .chip {
            display: inline-block;
            padding: 7px 10px;
            border-radius: 999px;
            background: #e5e7eb;
            color: #374151;
            font-size: 12px;
            font-weight: 700;
        }

        .composer-textarea {
            width: 100%;
            min-height: 90px;
            height: 90px;
            max-height: 260px;
            resize: none;
            overflow-y: auto;
            border: none;
            outline: none;
            padding: 18px;
            background: #0f172a;
            color: #e5e7eb;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.7;
        }

        .composer-footer {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-top: 1px solid var(--line);
            background: white;
        }

        .composer-tip {
            color: var(--muted);
            font-size: 14px;
        }

        .send-btn {
            border: none;
            background: var(--blue);
            color: white;
            padding: 13px 20px;
            border-radius: 14px;
            font-size: 15px;
            font-weight: 800;
            cursor: pointer;
        }

        .send-btn:hover {
            background: var(--blue-dark);
        }

        @media (max-width: 900px) {
            .score-grid {
                grid-template-columns: repeat(2, 1fr);
            }

            .analysis-grid {
                grid-template-columns: 1fr;
            }
        }

        @media (max-width: 640px) {
            body {
                padding-bottom: 330px;
            }

            h1 {
                font-size: 32px;
            }

            .composer-toolbar,
            .composer-footer {
                flex-direction: column;
                align-items: stretch;
            }

            .toolbar-left,
            .toolbar-right {
                width: 100%;
            }

            .mode-select {
                width: 100%;
            }

            .score-grid {
                grid-template-columns: 1fr;
            }

            .composer-wrap {
                width: calc(100vw - 16px);
                bottom: 8px;
            }

            .composer-textarea {
                min-height: 78px;
                height: 78px;
                max-height: 220px;
            }
        }
    </style>
</head>
<body>
    <div class="page">
        <header class="topbar">
            <div class="eyebrow">LLM + Rule-based Review</div>
            <h1>PromptCode</h1>
            <p class="subtitle">
                Python code review workspace with natural language chat support and persistent in-page history.
            </p>

            <div class="clear-row">
                <form method="post" action="/">
                    <input type="hidden" name="action" value="clear">
                    <button type="submit" class="ghost-btn">Clear Current Session</button>
                </form>
            </div>
        </header>

        {% if error %}
        <div class="error-banner">{{ error }}</div>
        {% endif %}

        <main class="history" id="history">
            {% if history|length == 0 %}
            <section class="welcome-card">
                <h2>Start your first message</h2>
                <p>
                    You can paste Python code for review, or ask natural language questions like:
                    "Write a Python hello world program".
                </p>
            </section>
            {% endif %}

            {% for item in history %}
            <div class="turn">
                <section class="user-card">
                    <div class="card-top">
                        <span class="pill pill-user">You</span>
                        <span class="pill pill-mode">{{ item.mode }}</span>
                    </div>
                    <div class="section-title">
                        {% if item.input_kind == "chat" %}Your Message{% else %}Submitted Code{% endif %}
                    </div>
                    <pre class="code-block">{{ item.user_code }}</pre>
                </section>

                <section class="assistant-card">
                    <div class="card-top">
                        <span class="pill pill-assistant">PromptCode</span>
                    </div>

                    {% if item.input_kind == "chat" %}
                    <section class="summary-box">
                        <h3>Assistant Response</h3>
                        <p>{{ item.result.summary }}</p>
                    </section>
                    {% else %}
                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary }}</p>
                    </section>

                    <div class="score-grid">
                        <div class="score-box">
                            <span class="score-label">Correctness</span>
                            <span class="score-value">{{ item.result.scores.correctness }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Readability</span>
                            <span class="score-value">{{ item.result.scores.readability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Maintainability</span>
                            <span class="score-value">{{ item.result.scores.maintainability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Documentation</span>
                            <span class="score-value">{{ item.result.scores.documentation_quality }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Overall</span>
                            <span class="score-value">{{ item.result.overall_score }}</span>
                        </div>
                    </div>

                    <div class="analysis-grid">
                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                        </section>
                    </div>

                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                    </section>

                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        <pre class="code-block">{{ item.result.improved_code }}</pre>
                    </section>
                    {% endif %}
                </section>
            </div>
            {% endfor %}
        </main>
    </div>

    <div class="composer-wrap">
        <section class="composer">
            <form action="/" method="post">
                <input type="hidden" name="action" value="review">

                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="auto" {% if mode == "auto" %}selected{% endif %}>Auto</option>
                            <option value="chat" {% if mode == "chat" %}selected{% endif %}>Chat</option>
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="chip">Python only</span>
                        <span class="chip">Natural language supported</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Paste Python code, or ask something like: write a Python hello world program"
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="composer-tip">Auto mode detects code vs natural language. The composer stays visible while you scroll.</div>
                    <button type="submit" class="send-btn">Send</button>
                </div>
            </form>
        </section>
    </div>

    <script>
        const textarea = document.getElementById("code");

        function autoResize(el) {
            el.style.height = "90px";
            const next = Math.min(el.scrollHeight, 260);
            el.style.height = next + "px";
        }

        window.addEventListener("load", function () {
            autoResize(textarea);
            window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });
        });

        textarea.addEventListener("input", function () {
            autoResize(textarea);
        });
    </script>
</body>
</html>
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>

    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/themes/prism.min.css">
    <script src="https://cdn.jsdelivr.net/npm/marked/marked.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/prism.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-python.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-javascript.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-java.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-sql.min.js"></script>

    <style>
        * { box-sizing: border-box; }

        :root {
            --bg: #f7f7fb;
            --panel: #ffffff;
            --line: #e5e7eb;
            --text: #111827;
            --muted: #6b7280;
            --blue: #2563eb;
            --blue-dark: #1d4ed8;
            --shadow: 0 10px 30px rgba(15, 23, 42, 0.10);
            --radius: 18px;
        }

        html, body {
            margin: 0;
            padding: 0;
            background: var(--bg);
            color: var(--text);
            font-family: Arial, Helvetica, sans-serif;
        }

        body {
            padding-bottom: 260px;
        }

        .page {
            max-width: 1000px;
            margin: 0 auto;
            padding: 28px 18px 24px;
        }

        .topbar {
            margin-bottom: 22px;
        }

        .eyebrow {
            display: inline-block;
            background: #dbeafe;
            color: #1d4ed8;
            padding: 8px 12px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
            margin-bottom: 12px;
        }

        h1 {
            font-size: 44px;
            margin: 0 0 10px;
        }

        .subtitle {
            margin: 0;
            color: var(--muted);
            line-height: 1.7;
            max-width: 760px;
        }

        .clear-row {
            margin-top: 14px;
        }

        .ghost-btn {
            border: 1px solid var(--line);
            background: white;
            color: #374151;
            padding: 10px 14px;
            border-radius: 12px;
            font-weight: 700;
            cursor: pointer;
        }

        .ghost-btn:hover {
            background: #f3f4f6;
        }

        .error-banner {
            background: #fff7ed;
            border: 1px solid #fdba74;
            color: #9a3412;
            padding: 14px 16px;
            border-radius: 14px;
            margin-bottom: 16px;
        }

        .history {
            display: flex;
            flex-direction: column;
            gap: 18px;
        }

        .welcome-card,
        .user-card,
        .assistant-card,
        .mini-panel,
        .summary-box,
        .wide-panel,
        .score-box,
        .chat-panel {
            background: var(--panel);
            border: 1px solid var(--line);
            border-radius: var(--radius);
            box-shadow: var(--shadow);
        }

        .welcome-card {
            padding: 24px;
        }

        .welcome-card h2 {
            margin: 0 0 10px;
        }

        .welcome-card p {
            margin: 0;
            color: var(--muted);
            line-height: 1.8;
        }

        .turn {
            display: flex;
            flex-direction: column;
            gap: 12px;
        }

        .user-card {
            padding: 20px;
            background: #eef4ff;
        }

        .assistant-card {
            padding: 20px;
        }

        .card-top {
            display: flex;
            gap: 8px;
            align-items: center;
            margin-bottom: 10px;
            flex-wrap: wrap;
        }

        .pill {
            display: inline-block;
            padding: 6px 10px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
        }

        .pill-user {
            background: #bfdbfe;
            color: #1d4ed8;
        }

        .pill-assistant {
            background: #dcfce7;
            color: #166534;
        }

        .pill-mode {
            background: #e5e7eb;
            color: #374151;
        }

        .section-title {
            margin: 0 0 10px;
            font-size: 20px;
        }

        .code-wrap {
            position: relative;
        }

        .copy-btn {
            position: absolute;
            top: 10px;
            right: 10px;
            border: none;
            background: rgba(255,255,255,0.15);
            color: #ffffff;
            padding: 8px 10px;
            border-radius: 10px;
            cursor: pointer;
            font-size: 12px;
            font-weight: 700;
        }

        .copy-btn:hover {
            background: rgba(255,255,255,0.25);
        }

        .code-block {
            margin: 0;
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.6;
            white-space: pre-wrap;
        }

        .summary-box,
        .wide-panel,
        .chat-panel {
            padding: 16px;
            margin-bottom: 12px;
            background: #f8fafc;
        }

        .summary-box p {
            margin: 0;
            line-height: 1.8;
            color: #374151;
            white-space: pre-wrap;
        }

        .score-grid {
            display: grid;
            grid-template-columns: repeat(5, 1fr);
            gap: 10px;
            margin-bottom: 12px;
        }

        .score-box {
            padding: 16px;
            text-align: center;
        }

        .score-label {
            display: block;
            font-size: 13px;
            color: var(--muted);
            margin-bottom: 8px;
            font-weight: 700;
        }

        .score-value {
            font-size: 28px;
            font-weight: 800;
        }

        .analysis-grid {
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 12px;
            margin-bottom: 12px;
        }

        .mini-panel {
            padding: 16px;
            background: #f8fafc;
        }

        .mini-panel h3,
        .wide-panel h3,
        .chat-panel h3 {
            margin: 0 0 10px;
            font-size: 18px;
        }

        .clean-list {
            margin: 0;
            padding-left: 20px;
            line-height: 1.8;
            color: #374151;
        }

        .markdown-body {
            line-height: 1.8;
            color: #374151;
        }

        .markdown-body pre {
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
        }

        .markdown-body code {
            font-family: Consolas, Menlo, monospace;
        }

        .composer-wrap {
            position: fixed;
            left: 50%;
            transform: translateX(-50%);
            bottom: 16px;
            width: min(1000px, calc(100vw - 24px));
            z-index: 9999;
        }

        .composer {
            background: rgba(255,255,255,0.98);
            border: 1px solid var(--line);
            border-radius: 22px;
            box-shadow: 0 20px 50px rgba(15, 23, 42, 0.18);
            overflow: hidden;
            backdrop-filter: blur(10px);
        }

        .composer-toolbar {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-bottom: 1px solid var(--line);
            background: #f8fafc;
        }

        .toolbar-left {
            display: flex;
            align-items: center;
            gap: 10px;
        }

        .toolbar-label {
            font-size: 14px;
            font-weight: 700;
            color: #374151;
        }

        .mode-select {
            border: 1px solid #cbd5e1;
            border-radius: 12px;
            padding: 10px 12px;
            background: white;
            font-size: 14px;
            outline: none;
        }

        .mode-select:focus {
            border-color: var(--blue);
            box-shadow: 0 0 0 4px rgba(37,99,235,0.12);
        }

        .toolbar-right {
            display: flex;
            gap: 8px;
            flex-wrap: wrap;
        }

        .chip {
            display: inline-block;
            padding: 7px 10px;
            border-radius: 999px;
            background: #e5e7eb;
            color: #374151;
            font-size: 12px;
            font-weight: 700;
        }

        .composer-textarea {
            width: 100%;
            min-height: 90px;
            height: 90px;
            max-height: 260px;
            resize: none;
            overflow-y: auto;
            border: none;
            outline: none;
            padding: 18px;
            background: #0f172a;
            color: #e5e7eb;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.7;
        }

        .composer-footer {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-top: 1px solid var(--line);
            background: white;
        }

        .composer-tip {
            color: var(--muted);
            font-size: 14px;
        }

        .send-btn {
            border: none;
            background: var(--blue);
            color: white;
            padding: 13px 20px;
            border-radius: 14px;
            font-size: 15px;
            font-weight: 800;
            cursor: pointer;
        }

        .send-btn:hover {
            background: var(--blue-dark);
        }

        @media (max-width: 900px) {
            .score-grid {
                grid-template-columns: repeat(2, 1fr);
            }

            .analysis-grid {
                grid-template-columns: 1fr;
            }
        }

        @media (max-width: 640px) {
            body {
                padding-bottom: 330px;
            }

            h1 {
                font-size: 32px;
            }

            .composer-toolbar,
            .composer-footer {
                flex-direction: column;
                align-items: stretch;
            }

            .toolbar-left,
            .toolbar-right {
                width: 100%;
            }

            .mode-select {
                width: 100%;
            }

            .score-grid {
                grid-template-columns: 1fr;
            }

            .composer-wrap {
                width: calc(100vw - 16px);
                bottom: 8px;
            }

            .composer-textarea {
                min-height: 78px;
                height: 78px;
                max-height: 220px;
            }
        }
    </style>
</head>
<body>
    <div class="page">
        <header class="topbar">
            <div class="eyebrow">LLM + Rule-based Review</div>
            <h1>PromptCode</h1>
            <p class="subtitle">
                Python code review workspace with natural language chat support, multi-language generation, markdown rendering, syntax highlight, and copy buttons.
            </p>

            <div class="clear-row">
                <form method="post" action="/">
                    <input type="hidden" name="action" value="clear">
                    <button type="submit" class="ghost-btn">Clear Current Session</button>
                </form>
            </div>
        </header>

        {% if error %}
        <div class="error-banner">{{ error }}</div>
        {% endif %}

        <main class="history" id="history">
            {% if history|length == 0 %}
            <section class="welcome-card">
                <h2>Start your first message</h2>
                <p>
                    Try:
                    <br><br>
                    “给我一个 Python hello world”
                    <br>
                    “Write a Java hello world”
                    <br>
                    “Review this Python function”
                </p>
            </section>
            {% endif %}

            {% for item in history %}
            <div class="turn">
                <section class="user-card">
                    <div class="card-top">
                        <span class="pill pill-user">You</span>
                        <span class="pill pill-mode">{{ item.mode }}</span>
                        <span class="pill pill-mode">{{ item.language }}</span>
                    </div>

                    <div class="section-title">
                        {% if item.input_kind == "chat" %}Your Message{% else %}Submitted Code{% endif %}
                    </div>

                    <div class="code-wrap">
                        <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                        <pre class="code-block">{{ item.user_code }}</pre>
                    </div>
                </section>

                <section class="assistant-card">
                    <div class="card-top">
                        <span class="pill pill-assistant">PromptCode</span>
                    </div>

                    {% if item.input_kind == "chat" %}
                    <section class="chat-panel">
                        <h3>Assistant Response</h3>
                        <div class="markdown-body render-markdown">{{ item.result.summary }}</div>
                    </section>
                    {% else %}
                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary }}</p>
                    </section>

                    <div class="score-grid">
                        <div class="score-box">
                            <span class="score-label">Correctness</span>
                            <span class="score-value">{{ item.result.scores.correctness }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Readability</span>
                            <span class="score-value">{{ item.result.scores.readability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Maintainability</span>
                            <span class="score-value">{{ item.result.scores.maintainability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Documentation</span>
                            <span class="score-value">{{ item.result.scores.documentation_quality }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Overall</span>
                            <span class="score-value">{{ item.result.overall_score }}</span>
                        </div>
                    </div>

                    <div class="analysis-grid">
                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                        </section>
                    </div>

                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                    </section>

                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        <div class="code-wrap">
                            <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                            <pre class="code-block">{{ item.result.improved_code }}</pre>
                        </div>
                    </section>
                    {% endif %}
                </section>
            </div>
            {% endfor %}
        </main>
    </div>

    <div class="composer-wrap">
        <section class="composer">
            <form action="/" method="post">
                <input type="hidden" name="action" value="send">

                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="auto" {% if mode == "auto" %}selected{% endif %}>Auto</option>
                            <option value="chat" {% if mode == "chat" %}selected{% endif %}>Chat</option>
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="chip">Multi-language</span>
                        <span class="chip">Markdown + Highlight</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Ask naturally, or paste code. Example: 给我一个 Python hello world"
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="composer-tip">Auto mode detects natural language vs code. Chat mode is best for asking directly.</div>
                    <button type="submit" class="send-btn">Send</button>
                </div>
            </form>
        </section>
    </div>

    <script>
        const textarea = document.getElementById("code");

        function autoResize(el) {
            el.style.height = "90px";
            const next = Math.min(el.scrollHeight, 260);
            el.style.height = next + "px";
        }

        function copyText(button) {
            const pre = button.parentElement.querySelector("pre");
            if (!pre) return;
            navigator.clipboard.writeText(pre.innerText);
            button.innerText = "Copied";
            setTimeout(() => {
                button.innerText = "Copy";
            }, 1200);
        }

        function renderMarkdownBlocks() {
            const blocks = document.querySelectorAll(".render-markdown");
            blocks.forEach((block) => {
                const raw = block.textContent;
                block.innerHTML = marked.parse(raw);
            });
            Prism.highlightAll();
        }

        window.addEventListener("load", function () {
            autoResize(textarea);
            renderMarkdownBlocks();
            window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });
        });

        textarea.addEventListener("input", function () {
            autoResize(textarea);
        });
    </script>
</body>
</html>
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>

    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/themes/prism.min.css">
    <script src="https://cdn.jsdelivr.net/npm/marked/marked.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/prism.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-python.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-javascript.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-java.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-sql.min.js"></script>

    <style>
        * { box-sizing: border-box; }

        :root {
            --bg: #f7f7fb;
            --panel: #ffffff;
            --line: #e5e7eb;
            --text: #111827;
            --muted: #6b7280;
            --blue: #2563eb;
            --blue-dark: #1d4ed8;
            --shadow: 0 10px 30px rgba(15, 23, 42, 0.10);
            --radius: 18px;
        }

        html, body {
            margin: 0;
            padding: 0;
            background: var(--bg);
            color: var(--text);
            font-family: Arial, Helvetica, sans-serif;
        }

        body {
            padding-bottom: 260px;
        }

        .page {
            max-width: 1000px;
            margin: 0 auto;
            padding: 28px 18px 24px;
        }

        .topbar {
            margin-bottom: 22px;
        }

        .eyebrow {
            display: inline-block;
            background: #dbeafe;
            color: #1d4ed8;
            padding: 8px 12px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
            margin-bottom: 12px;
        }

        h1 {
            font-size: 44px;
            margin: 0 0 10px;
        }

        .subtitle {
            margin: 0;
            color: var(--muted);
            line-height: 1.7;
            max-width: 760px;
        }

        .clear-row {
            margin-top: 14px;
        }

        .ghost-btn {
            border: 1px solid var(--line);
            background: white;
            color: #374151;
            padding: 10px 14px;
            border-radius: 12px;
            font-weight: 700;
            cursor: pointer;
        }

        .ghost-btn:hover {
            background: #f3f4f6;
        }

        .error-banner {
            background: #fff7ed;
            border: 1px solid #fdba74;
            color: #9a3412;
            padding: 14px 16px;
            border-radius: 14px;
            margin-bottom: 16px;
        }

        .history {
            display: flex;
            flex-direction: column;
            gap: 18px;
        }

        .welcome-card,
        .user-card,
        .assistant-card,
        .mini-panel,
        .summary-box,
        .wide-panel,
        .score-box,
        .chat-panel {
            background: var(--panel);
            border: 1px solid var(--line);
            border-radius: var(--radius);
            box-shadow: var(--shadow);
        }

        .welcome-card {
            padding: 24px;
        }

        .welcome-card h2 {
            margin: 0 0 10px;
        }

        .welcome-card p {
            margin: 0;
            color: var(--muted);
            line-height: 1.8;
        }

        .turn {
            display: flex;
            flex-direction: column;
            gap: 12px;
        }

        .user-card {
            padding: 20px;
            background: #eef4ff;
        }

        .assistant-card {
            padding: 20px;
        }

        .card-top {
            display: flex;
            gap: 8px;
            align-items: center;
            margin-bottom: 10px;
            flex-wrap: wrap;
        }

        .pill {
            display: inline-block;
            padding: 6px 10px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
        }

        .pill-user {
            background: #bfdbfe;
            color: #1d4ed8;
        }

        .pill-assistant {
            background: #dcfce7;
            color: #166534;
        }

        .pill-mode {
            background: #e5e7eb;
            color: #374151;
        }

        .section-title {
            margin: 0 0 10px;
            font-size: 20px;
        }

        .code-wrap {
            position: relative;
        }

        .copy-btn {
            position: absolute;
            top: 10px;
            right: 10px;
            border: none;
            background: rgba(255,255,255,0.15);
            color: #ffffff;
            padding: 8px 10px;
            border-radius: 10px;
            cursor: pointer;
            font-size: 12px;
            font-weight: 700;
            z-index: 3;
        }

        .copy-btn:hover {
            background: rgba(255,255,255,0.25);
        }

        .markdown-copy-btn {
            position: absolute;
            top: 10px;
            right: 10px;
            border: none;
            background: rgba(255,255,255,0.15);
            color: #ffffff;
            padding: 8px 10px;
            border-radius: 10px;
            cursor: pointer;
            font-size: 12px;
            font-weight: 700;
            z-index: 3;
        }

        .markdown-copy-btn:hover {
            background: rgba(255,255,255,0.25);
        }

        .code-block {
            margin: 0;
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.6;
            white-space: pre-wrap;
        }

        .summary-box,
        .wide-panel,
        .chat-panel {
            padding: 16px;
            margin-bottom: 12px;
            background: #f8fafc;
        }

        .summary-box p {
            margin: 0;
            line-height: 1.8;
            color: #374151;
            white-space: pre-wrap;
        }

        .score-grid {
            display: grid;
            grid-template-columns: repeat(5, 1fr);
            gap: 10px;
            margin-bottom: 12px;
        }

        .score-box {
            padding: 16px;
            text-align: center;
        }

        .score-label {
            display: block;
            font-size: 13px;
            color: var(--muted);
            margin-bottom: 8px;
            font-weight: 700;
        }

        .score-value {
            font-size: 28px;
            font-weight: 800;
        }

        .analysis-grid {
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 12px;
            margin-bottom: 12px;
        }

        .mini-panel {
            padding: 16px;
            background: #f8fafc;
        }

        .mini-panel h3,
        .wide-panel h3,
        .chat-panel h3 {
            margin: 0 0 10px;
            font-size: 18px;
        }

        .clean-list {
            margin: 0;
            padding-left: 20px;
            line-height: 1.8;
            color: #374151;
        }

        .markdown-body {
            line-height: 1.8;
            color: #374151;
        }

        .markdown-body pre {
            position: relative;
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
        }

        .markdown-body code {
            font-family: Consolas, Menlo, monospace;
        }

        .composer-wrap {
            position: fixed;
            left: 50%;
            transform: translateX(-50%);
            bottom: 16px;
            width: min(1000px, calc(100vw - 24px));
            z-index: 9999;
        }

        .composer {
            background: rgba(255,255,255,0.98);
            border: 1px solid var(--line);
            border-radius: 22px;
            box-shadow: 0 20px 50px rgba(15, 23, 42, 0.18);
            overflow: hidden;
            backdrop-filter: blur(10px);
        }

        .composer-toolbar {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-bottom: 1px solid var(--line);
            background: #f8fafc;
        }

        .toolbar-left {
            display: flex;
            align-items: center;
            gap: 10px;
        }

        .toolbar-label {
            font-size: 14px;
            font-weight: 700;
            color: #374151;
        }

        .mode-select {
            border: 1px solid #cbd5e1;
            border-radius: 12px;
            padding: 10px 12px;
            background: white;
            font-size: 14px;
            outline: none;
        }

        .mode-select:focus {
            border-color: var(--blue);
            box-shadow: 0 0 0 4px rgba(37,99,235,0.12);
        }

        .toolbar-right {
            display: flex;
            gap: 8px;
            flex-wrap: wrap;
        }

        .chip {
            display: inline-block;
            padding: 7px 10px;
            border-radius: 999px;
            background: #e5e7eb;
            color: #374151;
            font-size: 12px;
            font-weight: 700;
        }

        .composer-textarea {
            width: 100%;
            min-height: 90px;
            height: 90px;
            max-height: 260px;
            resize: none;
            overflow-y: auto;
            border: none;
            outline: none;
            padding: 18px;
            background: #0f172a;
            color: #e5e7eb;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.7;
        }

        .composer-footer {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-top: 1px solid var(--line);
            background: white;
        }

        .composer-tip {
            color: var(--muted);
            font-size: 14px;
        }

        .send-btn {
            border: none;
            background: var(--blue);
            color: white;
            padding: 13px 20px;
            border-radius: 14px;
            font-size: 15px;
            font-weight: 800;
            cursor: pointer;
            min-width: 96px;
        }

        .send-btn:hover {
            background: var(--blue-dark);
        }

        .send-btn:disabled {
            background: #93c5fd;
            cursor: not-allowed;
        }

        @media (max-width: 900px) {
            .score-grid {
                grid-template-columns: repeat(2, 1fr);
            }

            .analysis-grid {
                grid-template-columns: 1fr;
            }
        }

        @media (max-width: 640px) {
            body {
                padding-bottom: 330px;
            }

            h1 {
                font-size: 32px;
            }

            .composer-toolbar,
            .composer-footer {
                flex-direction: column;
                align-items: stretch;
            }

            .toolbar-left,
            .toolbar-right {
                width: 100%;
            }

            .mode-select {
                width: 100%;
            }

            .score-grid {
                grid-template-columns: 1fr;
            }

            .composer-wrap {
                width: calc(100vw - 16px);
                bottom: 8px;
            }

            .composer-textarea {
                min-height: 78px;
                height: 78px;
                max-height: 220px;
            }
        }
    </style>
</head>
<body>
    <div class="page">
        <header class="topbar">
            <div class="eyebrow">LLM + Rule-based Review</div>
            <h1>PromptCode</h1>
            <p class="subtitle">
                Python code review workspace with natural language chat support, multi-language generation, markdown rendering, syntax highlight, and copy buttons.
            </p>

            <div class="clear-row">
                <form method="post" action="/">
                    <input type="hidden" name="action" value="clear">
                    <button type="submit" class="ghost-btn">Clear Current Session</button>
                </form>
            </div>
        </header>

        {% if error %}
        <div class="error-banner">{{ error }}</div>
        {% endif %}

        <main class="history" id="history">
            {% if history|length == 0 %}
            <section class="welcome-card">
                <h2>Start your first message</h2>
                <p>
                    Try:
                    <br><br>
                    “给我一个 Python hello world”
                    <br>
                    “Write a Java hello world”
                    <br>
                    “Review this Python function”
                </p>
            </section>
            {% endif %}

            {% for item in history %}
            <div class="turn">
                <section class="user-card">
                    <div class="card-top">
                        <span class="pill pill-user">You</span>
                        <span class="pill pill-mode">{{ item.mode }}</span>
                        <span class="pill pill-mode">{{ item.language }}</span>
                    </div>

                    <div class="section-title">
                        {% if item.input_kind == "chat" %}Your Message{% else %}Submitted Code{% endif %}
                    </div>

                    <div class="code-wrap">
                        <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                        <pre class="code-block">{{ item.user_code }}</pre>
                    </div>
                </section>

                <section class="assistant-card">
                    <div class="card-top">
                        <span class="pill pill-assistant">PromptCode</span>
                    </div>

                    {% if item.input_kind == "chat" %}
                    <section class="chat-panel">
                        <h3>Assistant Response</h3>
                        <div class="markdown-body render-markdown">{{ item.result.summary }}</div>
                    </section>
                    {% else %}
                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary }}</p>
                    </section>

                    <div class="score-grid">
                        <div class="score-box">
                            <span class="score-label">Correctness</span>
                            <span class="score-value">{{ item.result.scores.correctness }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Readability</span>
                            <span class="score-value">{{ item.result.scores.readability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Maintainability</span>
                            <span class="score-value">{{ item.result.scores.maintainability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Documentation</span>
                            <span class="score-value">{{ item.result.scores.documentation_quality }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Overall</span>
                            <span class="score-value">{{ item.result.overall_score }}</span>
                        </div>
                    </div>

                    <div class="analysis-grid">
                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                        </section>
                    </div>

                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                    </section>

                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        <div class="code-wrap">
                            <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                            <pre class="code-block">{{ item.result.improved_code }}</pre>
                        </div>
                    </section>
                    {% endif %}
                </section>
            </div>
            {% endfor %}
        </main>
    </div>

    <div class="composer-wrap">
        <section class="composer">
            <form action="/" method="post" id="composer-form">
                <input type="hidden" name="action" value="send">

                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="auto" {% if mode == "auto" %}selected{% endif %}>Auto</option>
                            <option value="chat" {% if mode == "chat" %}selected{% endif %}>Chat</option>
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="chip">Multi-language</span>
                        <span class="chip">Markdown + Highlight</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Ask naturally, or paste code. Example: 给我一个 Python hello world"
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="composer-tip">Auto mode detects natural language vs code. Chat mode is best for asking directly.</div>
                    <button type="submit" class="send-btn" id="send-btn">Send</button>
                </div>
            </form>
        </section>
    </div>

    <script>
        const textarea = document.getElementById("code");
        const composerForm = document.getElementById("composer-form");
        const sendBtn = document.getElementById("send-btn");

        function autoResize(el) {
            el.style.height = "90px";
            const next = Math.min(el.scrollHeight, 260);
            el.style.height = next + "px";
        }

        function copyText(button) {
            const pre = button.parentElement.querySelector("pre");
            if (!pre) return;
            navigator.clipboard.writeText(pre.innerText);
            button.innerText = "Copied";
            setTimeout(() => {
                button.innerText = "Copy";
            }, 1200);
        }

        function addCopyButtonsToMarkdownCode() {
            const codeBlocks = document.querySelectorAll(".markdown-body pre");
            codeBlocks.forEach((pre) => {
                if (pre.dataset.copyReady === "true") return;

                pre.dataset.copyReady = "true";
                const btn = document.createElement("button");
                btn.className = "markdown-copy-btn";
                btn.type = "button";
                btn.innerText = "Copy";
                btn.addEventListener("click", function () {
                    navigator.clipboard.writeText(pre.innerText);
                    btn.innerText = "Copied";
                    setTimeout(() => {
                        btn.innerText = "Copy";
                    }, 1200);
                });

                pre.style.position = "relative";
                pre.appendChild(btn);
            });
        }

        function renderMarkdownBlocks() {
            const blocks = document.querySelectorAll(".render-markdown");
            blocks.forEach((block) => {
                const raw = block.textContent;
                block.innerHTML = marked.parse(raw);
            });
            Prism.highlightAll();
            addCopyButtonsToMarkdownCode();
        }

        window.addEventListener("load", function () {
            autoResize(textarea);
            renderMarkdownBlocks();
            window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });
        });

        textarea.addEventListener("input", function () {
            autoResize(textarea);
        });

        composerForm.addEventListener("submit", function () {
            sendBtn.disabled = true;
            sendBtn.innerText = "Sending...";
        });
    </script>
</body>
</html>
""")

# %%
with open("index.html", "w", encoding="utf-8") as f:
    f.write("""<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>

    <link rel="stylesheet" href="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/themes/prism.min.css">
    <script src="https://cdn.jsdelivr.net/npm/marked/marked.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/prism.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-python.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-javascript.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-java.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-sql.min.js"></script>

    <style>
        * { box-sizing: border-box; }

        :root {
            --bg: #f7f7fb;
            --panel: #ffffff;
            --line: #e5e7eb;
            --text: #111827;
            --muted: #6b7280;
            --blue: #2563eb;
            --blue-dark: #1d4ed8;
            --shadow: 0 10px 30px rgba(15, 23, 42, 0.10);
            --radius: 18px;
        }

        html, body {
            margin: 0;
            padding: 0;
            background: var(--bg);
            color: var(--text);
            font-family: Arial, Helvetica, sans-serif;
        }

        body {
            padding-bottom: 260px;
        }

        .page {
            max-width: 1000px;
            margin: 0 auto;
            padding: 28px 18px 24px;
        }

        .topbar {
            margin-bottom: 22px;
        }

        .eyebrow {
            display: inline-block;
            background: #dbeafe;
            color: #1d4ed8;
            padding: 8px 12px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
            margin-bottom: 12px;
        }

        h1 {
            font-size: 44px;
            margin: 0 0 10px;
        }

        .subtitle {
            margin: 0;
            color: var(--muted);
            line-height: 1.7;
            max-width: 760px;
        }

        .clear-row {
            margin-top: 14px;
        }

        .ghost-btn {
            border: 1px solid var(--line);
            background: white;
            color: #374151;
            padding: 10px 14px;
            border-radius: 12px;
            font-weight: 700;
            cursor: pointer;
        }

        .ghost-btn:hover {
            background: #f3f4f6;
        }

        .error-banner {
            background: #fff7ed;
            border: 1px solid #fdba74;
            color: #9a3412;
            padding: 14px 16px;
            border-radius: 14px;
            margin-bottom: 16px;
        }

        .history {
            display: flex;
            flex-direction: column;
            gap: 18px;
        }

        .welcome-card,
        .user-card,
        .assistant-card,
        .mini-panel,
        .summary-box,
        .wide-panel,
        .score-box,
        .chat-panel {
            background: var(--panel);
            border: 1px solid var(--line);
            border-radius: var(--radius);
            box-shadow: var(--shadow);
        }

        .welcome-card {
            padding: 24px;
        }

        .welcome-card h2 {
            margin: 0 0 10px;
        }

        .welcome-card p {
            margin: 0;
            color: var(--muted);
            line-height: 1.8;
        }

        .turn {
            display: flex;
            flex-direction: column;
            gap: 12px;
        }

        .user-card {
            padding: 20px;
            background: #eef4ff;
        }

        .assistant-card {
            padding: 20px;
        }

        .card-top {
            display: flex;
            gap: 8px;
            align-items: center;
            margin-bottom: 10px;
            flex-wrap: wrap;
        }

        .pill {
            display: inline-block;
            padding: 6px 10px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
        }

        .pill-user {
            background: #bfdbfe;
            color: #1d4ed8;
        }

        .pill-assistant {
            background: #dcfce7;
            color: #166534;
        }

        .pill-mode {
            background: #e5e7eb;
            color: #374151;
        }

        .section-title {
            margin: 0 0 10px;
            font-size: 20px;
        }

        .code-wrap {
            position: relative;
        }

        .copy-btn {
            position: absolute;
            top: 10px;
            right: 10px;
            border: none;
            background: rgba(255,255,255,0.15);
            color: #ffffff;
            padding: 8px 10px;
            border-radius: 10px;
            cursor: pointer;
            font-size: 12px;
            font-weight: 700;
            z-index: 3;
        }

        .copy-btn:hover {
            background: rgba(255,255,255,0.25);
        }

        .markdown-copy-btn {
            position: absolute;
            top: 10px;
            right: 10px;
            border: none;
            background: rgba(255,255,255,0.15);
            color: #ffffff;
            padding: 8px 10px;
            border-radius: 10px;
            cursor: pointer;
            font-size: 12px;
            font-weight: 700;
            z-index: 3;
        }

        .markdown-copy-btn:hover {
            background: rgba(255,255,255,0.25);
        }

        .code-block {
            margin: 0;
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.6;
            white-space: pre-wrap;
        }

        .summary-box,
        .wide-panel,
        .chat-panel {
            padding: 16px;
            margin-bottom: 12px;
            background: #f8fafc;
        }

        .summary-box p {
            margin: 0;
            line-height: 1.8;
            color: #374151;
            white-space: pre-wrap;
        }

        .score-grid {
            display: grid;
            grid-template-columns: repeat(5, 1fr);
            gap: 10px;
            margin-bottom: 12px;
        }

        .score-box {
            padding: 16px;
            text-align: center;
        }

        .score-label {
            display: block;
            font-size: 13px;
            color: var(--muted);
            margin-bottom: 8px;
            font-weight: 700;
        }

        .score-value {
            font-size: 28px;
            font-weight: 800;
        }

        .analysis-grid {
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 12px;
            margin-bottom: 12px;
        }

        .mini-panel {
            padding: 16px;
            background: #f8fafc;
        }

        .mini-panel h3,
        .wide-panel h3,
        .chat-panel h3 {
            margin: 0 0 10px;
            font-size: 18px;
        }

        .clean-list {
            margin: 0;
            padding-left: 20px;
            line-height: 1.8;
            color: #374151;
        }

        .markdown-body {
            line-height: 1.8;
            color: #374151;
        }

        .markdown-body pre {
            position: relative;
            background: #0f172a;
            color: #e5e7eb;
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
        }

        .markdown-body code {
            font-family: Consolas, Menlo, monospace;
        }

        .composer-wrap {
            position: fixed;
            left: 50%;
            transform: translateX(-50%);
            bottom: 16px;
            width: min(1000px, calc(100vw - 24px));
            z-index: 9999;
        }

        .composer {
            background: rgba(255,255,255,0.98);
            border: 1px solid var(--line);
            border-radius: 22px;
            box-shadow: 0 20px 50px rgba(15, 23, 42, 0.18);
            overflow: hidden;
            backdrop-filter: blur(10px);
        }

        .composer-toolbar {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-bottom: 1px solid var(--line);
            background: #f8fafc;
        }

        .toolbar-left {
            display: flex;
            align-items: center;
            gap: 10px;
        }

        .toolbar-label {
            font-size: 14px;
            font-weight: 700;
            color: #374151;
        }

        .mode-select {
            border: 1px solid #cbd5e1;
            border-radius: 12px;
            padding: 10px 12px;
            background: white;
            font-size: 14px;
            outline: none;
        }

        .mode-select:focus {
            border-color: var(--blue);
            box-shadow: 0 0 0 4px rgba(37,99,235,0.12);
        }

        .toolbar-right {
            display: flex;
            gap: 8px;
            flex-wrap: wrap;
        }

        .chip {
            display: inline-block;
            padding: 7px 10px;
            border-radius: 999px;
            background: #e5e7eb;
            color: #374151;
            font-size: 12px;
            font-weight: 700;
        }

        .composer-textarea {
            width: 100%;
            min-height: 90px;
            height: 90px;
            max-height: 260px;
            resize: none;
            overflow-y: auto;
            border: none;
            outline: none;
            padding: 18px;
            background: #0f172a;
            color: #e5e7eb;
            font-family: Consolas, Menlo, monospace;
            font-size: 14px;
            line-height: 1.7;
        }

        .composer-footer {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-top: 1px solid var(--line);
            background: white;
        }

        .composer-tip {
            color: var(--muted);
            font-size: 14px;
        }

        .send-btn {
            border: none;
            background: var(--blue);
            color: white;
            padding: 13px 20px;
            border-radius: 14px;
            font-size: 15px;
            font-weight: 800;
            cursor: pointer;
            min-width: 96px;
        }

        .send-btn:hover {
            background: var(--blue-dark);
        }

        .send-btn:disabled {
            background: #93c5fd;
            cursor: not-allowed;
        }

        @media (max-width: 900px) {
            .score-grid {
                grid-template-columns: repeat(2, 1fr);
            }

            .analysis-grid {
                grid-template-columns: 1fr;
            }
        }

        @media (max-width: 640px) {
            body {
                padding-bottom: 330px;
            }

            h1 {
                font-size: 32px;
            }

            .composer-toolbar,
            .composer-footer {
                flex-direction: column;
                align-items: stretch;
            }

            .toolbar-left,
            .toolbar-right {
                width: 100%;
            }

            .mode-select {
                width: 100%;
            }

            .score-grid {
                grid-template-columns: 1fr;
            }

            .composer-wrap {
                width: calc(100vw - 16px);
                bottom: 8px;
            }

            .composer-textarea {
                min-height: 78px;
                height: 78px;
                max-height: 220px;
            }
        }
    </style>
</head>
<body>
    <div class="page">
        <header class="topbar">
            <div class="eyebrow">LLM + Rule-based Review</div>
            <h1>PromptCode</h1>
            <p class="subtitle">
                Code review workspace with natural language chat support, multi-language generation, markdown rendering, syntax highlight, and copy buttons.
            </p>

            <div class="clear-row">
                <form method="post" action="/">
                    <input type="hidden" name="action" value="clear">
                    <button type="submit" class="ghost-btn">Clear Current Session</button>
                </form>
            </div>
        </header>

        {% if error %}
        <div class="error-banner">{{ error }}</div>
        {% endif %}

        <main class="history" id="history">
            {% if history|length == 0 %}
            <section class="welcome-card">
                <h2>Start your first message</h2>
                <p>
                    Try:
                    <br><br>
                    "Give me a Python hello world"
                    <br>
                    "Write a Java hello world"
                    <br>
                    "Review this Python function"
                </p>
            </section>
            {% endif %}

            {% for item in history %}
            <div class="turn">
                <section class="user-card">
                    <div class="card-top">
                        <span class="pill pill-user">You</span>
                        <span class="pill pill-mode">{{ item.mode }}</span>
                        <span class="pill pill-mode">{{ item.language }}</span>
                    </div>

                    <div class="section-title">
                        {% if item.input_kind == "chat" %}Your Message{% else %}Submitted Code{% endif %}
                    </div>

                    <div class="code-wrap">
                        <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                        <pre class="code-block">{{ item.user_code }}</pre>
                    </div>
                </section>

                <section class="assistant-card">
                    <div class="card-top">
                        <span class="pill pill-assistant">PromptCode</span>
                    </div>

                    {% if item.input_kind == "chat" %}
                    <section class="chat-panel">
                        <h3>Assistant Response</h3>
                        <div class="markdown-body render-markdown">{{ item.result.summary }}</div>
                    </section>
                    {% else %}
                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary }}</p>
                    </section>

                    <div class="score-grid">
                        <div class="score-box">
                            <span class="score-label">Correctness</span>
                            <span class="score-value">{{ item.result.scores.correctness }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Readability</span>
                            <span class="score-value">{{ item.result.scores.readability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Maintainability</span>
                            <span class="score-value">{{ item.result.scores.maintainability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Documentation</span>
                            <span class="score-value">{{ item.result.scores.documentation_quality }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Overall</span>
                            <span class="score-value">{{ item.result.overall_score }}</span>
                        </div>
                    </div>

                    <div class="analysis-grid">
                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                        </section>

                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                        </section>
                    </div>

                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                    </section>

                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        <div class="code-wrap">
                            <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                            <pre class="code-block">{{ item.result.improved_code }}</pre>
                        </div>
                    </section>
                    {% endif %}
                </section>
            </div>
            {% endfor %}
        </main>
    </div>

    <div class="composer-wrap">
        <section class="composer">
            <form action="/" method="post" id="composer-form">
                <input type="hidden" name="action" value="send">

                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="auto" {% if mode == "auto" %}selected{% endif %}>Auto</option>
                            <option value="chat" {% if mode == "chat" %}selected{% endif %}>Chat</option>
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="chip">Multi-language</span>
                        <span class="chip">Markdown + Highlight</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Ask naturally, or paste code. Example: Give me a Python hello world"
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="composer-tip">Auto mode detects natural language vs code. Chat mode is best for direct questions.</div>
                    <button type="submit" class="send-btn" id="send-btn">Send</button>
                </div>
            </form>
        </section>
    </div>

    <script>
        const textarea = document.getElementById("code");
        const composerForm = document.getElementById("composer-form");
        const sendBtn = document.getElementById("send-btn");

        function autoResize(el) {
            el.style.height = "90px";
            const next = Math.min(el.scrollHeight, 260);
            el.style.height = next + "px";
        }

        function copyText(button) {
            const pre = button.parentElement.querySelector("pre");
            if (!pre) return;
            navigator.clipboard.writeText(pre.innerText);
            button.innerText = "Copied";
            setTimeout(() => {
                button.innerText = "Copy";
            }, 1200);
        }

        function addCopyButtonsToMarkdownCode() {
            const codeBlocks = document.querySelectorAll(".markdown-body pre");
            codeBlocks.forEach((pre) => {
                if (pre.dataset.copyReady === "true") return;

                pre.dataset.copyReady = "true";
                const btn = document.createElement("button");
                btn.className = "markdown-copy-btn";
                btn.type = "button";
                btn.innerText = "Copy";
                btn.addEventListener("click", function () {
                    navigator.clipboard.writeText(pre.innerText);
                    btn.innerText = "Copied";
                    setTimeout(() => {
                        btn.innerText = "Copy";
                    }, 1200);
                });

                pre.style.position = "relative";
                pre.appendChild(btn);
            });
        }

        function renderMarkdownBlocks() {
            const blocks = document.querySelectorAll(".render-markdown");
            blocks.forEach((block) => {
                const raw = block.textContent;
                block.innerHTML = marked.parse(raw);
            });
            Prism.highlightAll();
            addCopyButtonsToMarkdownCode();
        }

        window.addEventListener("load", function () {
            autoResize(textarea);
            renderMarkdownBlocks();
            window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });
        });

        textarea.addEventListener("input", function () {
            autoResize(textarea);
        });

        composerForm.addEventListener("submit", function () {
            sendBtn.disabled = true;
            sendBtn.innerText = "Sending...";
        });
    </script>
</body>
</html>
""")

# %%
from pathlib import Path

html = r'''<!DOCTYPE html>
<html lang="en">
<head>
    <meta charset="UTF-8">
    <meta name="viewport" content="width=device-width, initial-scale=1.0">
    <title>PromptCode</title>

    <script src="https://cdn.jsdelivr.net/npm/marked/marked.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/prism.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-python.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-javascript.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-java.min.js"></script>
    <script src="https://cdn.jsdelivr.net/npm/prismjs@1.29.0/components/prism-sql.min.js"></script>

    <style>
        * { box-sizing: border-box; }

        :root {
            --bg: #f7f7fb;
            --panel: #ffffff;
            --line: #e5e7eb;
            --text: #111827;
            --muted: #6b7280;
            --blue: #2563eb;
            --blue-dark: #1d4ed8;
            --shadow: 0 10px 30px rgba(15, 23, 42, 0.10);
            --radius: 18px;
            --code-bg: #ffffff;
            --code-fg: #111111;
        }

        html, body {
            margin: 0;
            padding: 0;
            background: var(--bg);
            color: var(--text);
            font-family: Arial, Helvetica, sans-serif;
        }

        body {
            padding-bottom: 260px;
        }

        .page {
            max-width: 1000px;
            margin: 0 auto;
            padding: 28px 18px 24px;
        }

        .topbar {
            margin-bottom: 22px;
        }

        .eyebrow {
            display: inline-block;
            background: #dbeafe;
            color: #1d4ed8;
            padding: 8px 12px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
            margin-bottom: 12px;
        }

        h1 {
            font-size: 44px;
            margin: 0 0 10px;
        }

        .subtitle {
            margin: 0;
            color: var(--muted);
            line-height: 1.7;
            max-width: 760px;
        }

        .clear-row {
            margin-top: 14px;
        }

        .ghost-btn {
            border: 1px solid var(--line);
            background: white;
            color: #374151;
            padding: 10px 14px;
            border-radius: 12px;
            font-weight: 700;
            cursor: pointer;
        }

        .ghost-btn:hover {
            background: #f3f4f6;
        }

        .error-banner {
            background: #fff7ed;
            border: 1px solid #fdba74;
            color: #9a3412;
            padding: 14px 16px;
            border-radius: 14px;
            margin-bottom: 16px;
        }

        .history {
            display: flex;
            flex-direction: column;
            gap: 18px;
        }

        .welcome-card,
        .user-card,
        .assistant-card,
        .mini-panel,
        .summary-box,
        .wide-panel,
        .score-box,
        .chat-panel {
            background: var(--panel);
            border: 1px solid var(--line);
            border-radius: var(--radius);
            box-shadow: var(--shadow);
        }

        .welcome-card {
            padding: 24px;
        }

        .welcome-card h2 {
            margin: 0 0 10px;
        }

        .welcome-card p {
            margin: 0;
            color: var(--muted);
            line-height: 1.8;
        }

        .turn {
            display: flex;
            flex-direction: column;
            gap: 12px;
        }

        .user-card {
            padding: 20px;
            background: #eef4ff;
        }

        .assistant-card {
            padding: 20px;
        }

        .card-top {
            display: flex;
            gap: 8px;
            align-items: center;
            margin-bottom: 10px;
            flex-wrap: wrap;
        }

        .pill {
            display: inline-block;
            padding: 6px 10px;
            border-radius: 999px;
            font-size: 12px;
            font-weight: 700;
        }

        .pill-user {
            background: #bfdbfe;
            color: #1d4ed8;
        }

        .pill-assistant {
            background: #dcfce7;
            color: #166534;
        }

        .pill-mode {
            background: #e5e7eb;
            color: #374151;
        }

        .section-title {
            margin: 0 0 10px;
            font-size: 20px;
        }

        .code-wrap {
            position: relative;
        }

        .copy-btn {
            position: absolute;
            top: 8px;
            right: 8px;
            background: #f6f8fa;
            color: #24292f;
            border: 1px solid #d0d7de;
            padding: 6px 10px;
            border-radius: 6px;
            cursor: pointer;
            font-size: 12px;
            font-weight: 700;
            z-index: 10;
        }

        .copy-btn:hover {
            background: #eef2f6;
        }

        .markdown-copy-btn {
            position: absolute;
            top: 8px;
            right: 8px;
            background: #f6f8fa;
            color: #24292f;
            border: 1px solid #d0d7de;
            padding: 6px 10px;
            border-radius: 6px;
            cursor: pointer;
            font-size: 12px;
            font-weight: 700;
            z-index: 10;
        }

        .markdown-copy-btn:hover {
            background: #eef2f6;
        }

        .code-block {
            margin: 0;
            background: var(--code-bg);
            color: var(--code-fg);
            padding: 16px;
            border-radius: 14px;
            overflow-x: auto;
            font-family: "SFMono-Regular", Menlo, Monaco, Consolas, "Liberation Mono", monospace;
            font-size: 14px;
            line-height: 1.65;
            white-space: pre-wrap;
            text-shadow: none;
            -webkit-font-smoothing: auto;
            -moz-osx-font-smoothing: auto;
            border: 1px solid #d0d7de;
            background: #ffffff;
            color: #111111;
        }

        .summary-box,
        .wide-panel,
        .chat-panel {
            padding: 16px;
            margin-bottom: 12px;
            background: #f8fafc;
        }

        .summary-box p {
            margin: 0;
            line-height: 1.8;
            color: #374151;
            white-space: pre-wrap;
        }

        .score-grid {
            display: grid;
            grid-template-columns: repeat(5, 1fr);
            gap: 10px;
            margin-bottom: 12px;
        }

        .score-box {
            padding: 16px;
            text-align: center;
        }

        .score-label {
            display: block;
            font-size: 13px;
            color: var(--muted);
            margin-bottom: 8px;
            font-weight: 700;
        }

        .score-value {
            font-size: 28px;
            font-weight: 800;
        }

        .analysis-grid {
            display: grid;
            grid-template-columns: 1fr 1fr;
            gap: 12px;
            margin-bottom: 12px;
        }

        .mini-panel {
            padding: 16px;
            background: #f8fafc;
        }

        .mini-panel h3,
        .wide-panel h3,
        .chat-panel h3 {
            margin: 0 0 10px;
            font-size: 18px;
        }

        .clean-list {
            margin: 0;
            padding-left: 20px;
            line-height: 1.8;
            color: #374151;
        }

        .markdown-body {
            line-height: 1.8;
            color: #374151;
        }

        .markdown-body pre,
        pre[class*="language-"] {
            position: relative;
            background: #ffffff !important;
            color: #111111 !important;
            padding: 16px !important;
            border-radius: 14px !important;
            overflow-x: auto !important;
            text-shadow: none !important;
            border: 1px solid #d0d7de !important;
        }

        .markdown-body code,
        code[class*="language-"],
        pre[class*="language-"] {
            font-family: "SFMono-Regular", Menlo, Monaco, Consolas, "Liberation Mono", monospace !important;
            text-shadow: none !important;
            background: transparent !important;
            color: #111111 !important;
        }

        code[class*="language-"],
        pre[class*="language-"] {
            color: #111111 !important;
        }

        .token.comment,
        .token.prolog,
        .token.doctype,
        .token.cdata {
            color: #6e7781 !important;
            font-style: italic;
        }

        .token.punctuation {
            color: #24292f !important;
        }

        .token.property,
        .token.tag,
        .token.boolean,
        .token.number,
        .token.constant,
        .token.symbol,
        .token.deleted {
            color: #0550ae !important;
        }

        .token.selector,
        .token.attr-name,
        .token.string,
        .token.char,
        .token.builtin,
        .token.inserted {
            color: #0a3069 !important;
        }

        .token.operator,
        .token.entity,
        .token.url,
        .token.variable {
            color: #cf222e !important;
            background: transparent !important;
        }

        .token.atrule,
        .token.attr-value,
        .token.function,
        .token.class-name {
            color: #8250df !important;
        }

        .token.keyword {
            color: #cf222e !important;
            font-weight: 600;
        }

        .token.regex,
        .token.important {
            color: #9a6700 !important;
        }

        .token.namespace {
            opacity: 1 !important;
        }

        .token.bold {
            font-weight: bold;
        }

        .token.italic {
            font-style: italic;
        }

        .empty-state {
            margin: 0;
            color: var(--muted);
            font-size: 14px;
            line-height: 1.7;
            background: #ffffff;
            border: 1px dashed #d1d5db;
            border-radius: 12px;
            padding: 12px 14px;
        }

        .composer-wrap {
            position: fixed;
            left: 50%;
            transform: translateX(-50%);
            bottom: 16px;
            width: min(1000px, calc(100vw - 24px));
            z-index: 9999;
        }

        .composer {
            background: rgba(255,255,255,0.98);
            border: 1px solid var(--line);
            border-radius: 22px;
            box-shadow: 0 20px 50px rgba(15, 23, 42, 0.18);
            overflow: hidden;
            backdrop-filter: blur(10px);
        }

        .composer-toolbar {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-bottom: 1px solid var(--line);
            background: #f8fafc;
        }

        .toolbar-left {
            display: flex;
            align-items: center;
            gap: 10px;
        }

        .toolbar-label {
            font-size: 14px;
            font-weight: 700;
            color: #374151;
        }

        .mode-select {
            border: 1px solid #cbd5e1;
            border-radius: 12px;
            padding: 10px 12px;
            background: white;
            font-size: 14px;
            outline: none;
        }

        .mode-select:focus {
            border-color: var(--blue);
            box-shadow: 0 0 0 4px rgba(37,99,235,0.12);
        }

        .toolbar-right {
            display: flex;
            gap: 8px;
            flex-wrap: wrap;
        }

        .chip {
            display: inline-block;
            padding: 7px 10px;
            border-radius: 999px;
            background: #e5e7eb;
            color: #374151;
            font-size: 12px;
            font-weight: 700;
        }

        .composer-textarea {
            width: 100%;
            min-height: 90px;
            height: 90px;
            max-height: 260px;
            resize: none;
            overflow-y: auto;
            border: none;
            outline: none;
            padding: 18px;
            background: var(--code-bg);
            color: var(--code-fg);
            font-family: "SFMono-Regular", Menlo, Monaco, Consolas, "Liberation Mono", monospace;
            font-size: 14px;
            line-height: 1.7;
        }

        .composer-footer {
            display: flex;
            justify-content: space-between;
            align-items: center;
            gap: 12px;
            padding: 14px 16px;
            border-top: 1px solid var(--line);
            background: white;
        }

        .composer-tip {
            color: var(--muted);
            font-size: 14px;
        }

        .send-btn {
            border: none;
            background: var(--blue);
            color: white;
            padding: 13px 20px;
            border-radius: 14px;
            font-size: 15px;
            font-weight: 800;
            cursor: pointer;
            min-width: 96px;
        }

        .send-btn:hover {
            background: var(--blue-dark);
        }

        .send-btn:disabled {
            background: #93c5fd;
            cursor: not-allowed;
        }

        @media (max-width: 900px) {
            .score-grid {
                grid-template-columns: repeat(2, 1fr);
            }

            .analysis-grid {
                grid-template-columns: 1fr;
            }
        }

        @media (max-width: 640px) {
            body {
                padding-bottom: 330px;
            }

            h1 {
                font-size: 32px;
            }

            .composer-toolbar,
            .composer-footer {
                flex-direction: column;
                align-items: stretch;
            }

            .toolbar-left,
            .toolbar-right {
                width: 100%;
            }

            .mode-select {
                width: 100%;
            }

            .score-grid {
                grid-template-columns: 1fr;
            }

            .composer-wrap {
                width: calc(100vw - 16px);
                bottom: 8px;
            }

            .composer-textarea {
                min-height: 78px;
                height: 78px;
                max-height: 220px;
            }
        }
    </style>
</head>
<body>
    <div class="page">
        <header class="topbar">
            <div class="eyebrow">LLM + Rule-based Review</div>
            <h1>PromptCode</h1>
            <p class="subtitle">
                Code review workspace with natural language chat support, multi-language generation, markdown rendering, syntax highlight, and copy buttons.
            </p>

            <div class="clear-row">
                <form method="post" action="/">
                    <input type="hidden" name="action" value="clear">
                    <button type="submit" class="ghost-btn">Clear Current Session</button>
                </form>
            </div>
        </header>

        {% if error %}
        <div class="error-banner">{{ error }}</div>
        {% endif %}

        <main class="history" id="history">
            {% if history|length == 0 %}
            <section class="welcome-card">
                <h2>Start your first message</h2>
                <p>
                    Try:
                    <br><br>
                    "Give me a Python hello world"
                    <br>
                    "Write a Java hello world"
                    <br>
                    "Review this Python function"
                </p>
            </section>
            {% endif %}

            {% for item in history %}
            <div class="turn">
                <section class="user-card">
                    <div class="card-top">
                        <span class="pill pill-user">You</span>
                        <span class="pill pill-mode">{{ item.mode }}</span>
                        <span class="pill pill-mode">{{ item.language }}</span>
                    </div>

                    <div class="section-title">
                        {% if item.input_kind == "chat" %}Your Message{% else %}Submitted Code{% endif %}
                    </div>

                    <div class="code-wrap">
                        <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                        <pre class="code-block">{{ item.user_code }}</pre>
                    </div>
                </section>

                <section class="assistant-card">
                    <div class="card-top">
                        <span class="pill pill-assistant">PromptCode</span>
                    </div>

                    {% if item.input_kind == "chat" %}
                    <section class="chat-panel">
                        <h3>Assistant Response</h3>
                        <div class="markdown-body render-markdown">{{ item.result.summary }}</div>
                    </section>
                    {% else %}
                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary or "Review completed." }}</p>
                    </section>

                    <div class="score-grid">
                        <div class="score-box">
                            <span class="score-label">Correctness</span>
                            <span class="score-value">{{ item.result.scores.correctness }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Readability</span>
                            <span class="score-value">{{ item.result.scores.readability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Maintainability</span>
                            <span class="score-value">{{ item.result.scores.maintainability }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Documentation</span>
                            <span class="score-value">{{ item.result.scores.documentation_quality }}</span>
                        </div>
                        <div class="score-box">
                            <span class="score-label">Overall</span>
                            <span class="score-value">{{ item.result.overall_score }}</span>
                        </div>
                    </div>

                    <div class="analysis-grid">
                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            {% if item.result.bugs %}
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No bugs found.</p>
                            {% endif %}
                        </section>

                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            {% if item.result.style_issues %}
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No style issues found.</p>
                            {% endif %}
                        </section>

                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            {% if item.result.maintainability_issues %}
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No maintainability issues found.</p>
                            {% endif %}
                        </section>

                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            {% if item.result.documentation_issues %}
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No documentation issues found.</p>
                            {% endif %}
                        </section>
                    </div>

                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        {% if item.result.suggestions %}
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                        {% else %}
                        <p class="empty-state">No suggestions available.</p>
                        {% endif %}
                    </section>

                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        {% if item.result.improved_code %}
                        <div class="code-wrap">
                            <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                            <pre class="code-block">{{ item.result.improved_code }}</pre>
                        </div>
                        {% else %}
                        <p class="empty-state">No revised code available.</p>
                        {% endif %}
                    </section>
                    {% endif %}
                </section>
            </div>
            {% endfor %}
        </main>
    </div>

    <div class="composer-wrap">
        <section class="composer">
            <form action="/" method="post" id="composer-form">
                <input type="hidden" name="action" value="send">

                <div class="composer-toolbar">
                    <div class="toolbar-left">
                        <label for="mode" class="toolbar-label">Mode</label>
                        <select id="mode" name="mode" class="mode-select">
                            <option value="auto" {% if mode == "auto" %}selected{% endif %}>Auto</option>
                            <option value="chat" {% if mode == "chat" %}selected{% endif %}>Chat</option>
                            <option value="bug" {% if mode == "bug" %}selected{% endif %}>Bug Review</option>
                            <option value="style_docs" {% if mode == "style_docs" %}selected{% endif %}>Style & Docs Review</option>
                            <option value="full" {% if mode == "full" %}selected{% endif %}>Full Review</option>
                        </select>
                    </div>

                    <div class="toolbar-right">
                        <span class="chip">Multi-language</span>
                        <span class="chip">Markdown + Highlight</span>
                    </div>
                </div>

                <textarea
                    id="code"
                    name="code"
                    class="composer-textarea"
                    placeholder="Ask naturally, or paste code. Example: Give me a Python hello world"
                    required
                >{{ code }}</textarea>

                <div class="composer-footer">
                    <div class="composer-tip">Auto mode detects natural language vs code. Chat mode is best for direct questions.</div>
                    <button type="submit" class="send-btn" id="send-btn">Send</button>
                </div>
            </form>
        </section>
    </div>

    <script>
        marked.setOptions({
            highlight: function(code, lang) {
                if (lang && Prism.languages[lang]) {
                    return Prism.highlight(code, Prism.languages[lang], lang);
                }
                return code;
            }
        });

        const textarea = document.getElementById("code");
        const composerForm = document.getElementById("composer-form");
        const sendBtn = document.getElementById("send-btn");

        function autoResize(el) {
            el.style.height = "90px";
            const next = Math.min(el.scrollHeight, 260);
            el.style.height = next + "px";
        }

        function copyText(button) {
            const pre = button.parentElement.querySelector("pre");
            if (!pre) return;
            navigator.clipboard.writeText(pre.innerText);
            button.innerText = "Copied";
            setTimeout(() => {
                button.innerText = "Copy";
            }, 1200);
        }

        function addCopyButtonsToMarkdownCode() {
            const codeBlocks = document.querySelectorAll(".markdown-body pre");
            codeBlocks.forEach((pre) => {
                if (pre.dataset.copyReady === "true") return;

                pre.dataset.copyReady = "true";
                const btn = document.createElement("button");
                btn.className = "markdown-copy-btn";
                btn.type = "button";
                btn.innerText = "Copy";
                btn.addEventListener("click", function () {
                    navigator.clipboard.writeText(pre.innerText);
                    btn.innerText = "Copied";
                    setTimeout(() => {
                        btn.innerText = "Copy";
                    }, 1200);
                });

                pre.style.position = "relative";
                pre.appendChild(btn);
            });
        }

        function renderMarkdownBlocks() {
            const blocks = document.querySelectorAll(".render-markdown");
            blocks.forEach((block) => {
                const raw = block.textContent;
                block.innerHTML = marked.parse(raw);

                block.querySelectorAll("pre code").forEach((code) => {
                    const className = code.className || "";
                    const match = className.match(/language-([\w-]+)/);
                    if (match && code.parentElement && !code.parentElement.className.includes("language-")) {
                        code.parentElement.classList.add("language-" + match[1]);
                    }
                });
            });
            Prism.highlightAll();
            addCopyButtonsToMarkdownCode();
        }

        window.addEventListener("load", function () {
            autoResize(textarea);
            renderMarkdownBlocks();
            window.scrollTo({ top: document.body.scrollHeight, behavior: "smooth" });
        });

        textarea.addEventListener("input", function () {
            autoResize(textarea);
        });

        composerForm.addEventListener("submit", function () {
            sendBtn.disabled = true;
            sendBtn.innerText = "Sending...";
        });
    </script>
</body>
</html>
'''

# 这里改成你的 index.html 路径
path = Path("index.html")

# 自动备份旧文件
if path.exists():
    backup = path.with_suffix(".html.bak")
    backup.write_text(path.read_text(encoding="utf-8"), encoding="utf-8")
    print(f"Backup created: {backup}")

path.write_text(html, encoding="utf-8")
print(f"Updated: {path}")
# Out:
# Backup created: index.html.bak
# Updated: index.html

# %%
from pathlib import Path

# 改成你的真实路径
path = Path("index.html")

html = path.read_text(encoding="utf-8")

# 1) 如果还没有 empty-state 样式，就插入
empty_state_css = """
        .empty-state {
            margin: 0;
            color: var(--muted);
            font-size: 14px;
            line-height: 1.7;
            background: #ffffff;
            border: 1px dashed #d1d5db;
            border-radius: 12px;
            padding: 12px 14px;
        }
"""

if ".empty-state {" not in html:
    marker = """
        .token.italic {
            font-style: italic;
        }
"""
    replacement = marker + "\n" + empty_state_css
    html = html.replace(marker, replacement)

# 2) 替换 Bugs 区块
old_bugs = """                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                        </section>"""

new_bugs = """                        <section class="mini-panel">
                            <h3>Bugs</h3>
                            {% if item.result.bugs %}
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No bugs found.</p>
                            {% endif %}
                        </section>"""

html = html.replace(old_bugs, new_bugs)

# 3) 替换 Style Issues 区块
old_style = """                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                        </section>"""

new_style = """                        <section class="mini-panel">
                            <h3>Style Issues</h3>
                            {% if item.result.style_issues %}
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No style issues found.</p>
                            {% endif %}
                        </section>"""

html = html.replace(old_style, new_style)

# 4) 替换 Maintainability Issues 区块
old_maint = """                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                        </section>"""

new_maint = """                        <section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            {% if item.result.maintainability_issues %}
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No maintainability issues found.</p>
                            {% endif %}
                        </section>"""

html = html.replace(old_maint, new_maint)

# 5) 替换 Documentation Issues 区块
old_doc = """                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                        </section>"""

new_doc = """                        <section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            {% if item.result.documentation_issues %}
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No documentation issues found.</p>
                            {% endif %}
                        </section>"""

html = html.replace(old_doc, new_doc)

# 6) 替换 Suggestions 区块
old_suggestions = """                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                    </section>"""

new_suggestions = """                    <section class="wide-panel">
                        <h3>Suggestions</h3>
                        {% if item.result.suggestions %}
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                        {% else %}
                        <p class="empty-state">No suggestions available.</p>
                        {% endif %}
                    </section>"""

html = html.replace(old_suggestions, new_suggestions)

# 7) 替换 Improved Code 区块
old_improved = """                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        <div class="code-wrap">
                            <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                            <pre class="code-block">{{ item.result.improved_code }}</pre>
                        </div>
                    </section>"""

new_improved = """                    <section class="wide-panel">
                        <h3>Improved Code</h3>
                        {% if item.result.improved_code %}
                        <div class="code-wrap">
                            <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                            <pre class="code-block">{{ item.result.improved_code }}</pre>
                        </div>
                        {% else %}
                        <p class="empty-state">No revised code available.</p>
                        {% endif %}
                    </section>"""

html = html.replace(old_improved, new_improved)

# 8) summary 兜底
old_summary = """                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary }}</p>
                    </section>"""

new_summary = """                    <section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary or "Review completed." }}</p>
                    </section>"""

html = html.replace(old_summary, new_summary)

# 9) 备份并写回
backup = path.with_suffix(".html.bak")
backup.write_text(path.read_text(encoding="utf-8"), encoding="utf-8")
path.write_text(html, encoding="utf-8")

print(f"Backup created: {backup}")
print(f"Updated: {path}")
# Out:
# Backup created: index.html.bak
# Updated: index.html

# %%
from pathlib import Path
import re

# 1) 搜索当前目录下所有 index.html
candidates = list(Path(".").rglob("index.html"))

print("Found index.html files:")
for i, p in enumerate(candidates, 1):
    print(f"{i}. {p}")

target = None
for p in candidates:
    try:
        text = p.read_text(encoding="utf-8")
    except Exception:
        continue
    if "PromptCode" in text and "<h3>Bugs</h3>" in text:
        target = p
        break

if target is None:
    raise FileNotFoundError("Could not find the active PromptCode index.html template.")

print(f"\nUsing template: {target}")

html = target.read_text(encoding="utf-8")

# 2) 先备份
backup = target.with_suffix(".html.bak")
backup.write_text(html, encoding="utf-8")
print(f"Backup created: {backup}")

# 3) 如果没有 empty-state 样式，就插入
if ".empty-state {" not in html:
    insert_after = ".token.italic {\n            font-style: italic;\n        }\n"
    empty_css = """
        .empty-state {
            margin: 0;
            color: var(--muted);
            font-size: 14px;
            line-height: 1.7;
            background: #ffffff;
            border: 1px dashed #d1d5db;
            border-radius: 12px;
            padding: 12px 14px;
        }
"""
    if insert_after in html:
        html = html.replace(insert_after, insert_after + empty_css)
    else:
        print("Warning: CSS insertion point not found. Skipping CSS insert.")

# 4) 用正则强制替换各个区块
patterns = [
    (
        r'<section class="mini-panel">\s*<h3>Bugs</h3>\s*<ul class="clean-list">\s*{% for b in item\.result\.bugs %}\s*<li>{{ b }}</li>\s*{% endfor %}\s*</ul>\s*</section>',
        '''<section class="mini-panel">
                            <h3>Bugs</h3>
                            {% if item.result.bugs %}
                            <ul class="clean-list">
                                {% for b in item.result.bugs %}
                                <li>{{ b }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No bugs found.</p>
                            {% endif %}
                        </section>'''
    ),
    (
        r'<section class="mini-panel">\s*<h3>Style Issues</h3>\s*<ul class="clean-list">\s*{% for s in item\.result\.style_issues %}\s*<li>{{ s }}</li>\s*{% endfor %}\s*</ul>\s*</section>',
        '''<section class="mini-panel">
                            <h3>Style Issues</h3>
                            {% if item.result.style_issues %}
                            <ul class="clean-list">
                                {% for s in item.result.style_issues %}
                                <li>{{ s }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No style issues found.</p>
                            {% endif %}
                        </section>'''
    ),
    (
        r'<section class="mini-panel">\s*<h3>Maintainability Issues</h3>\s*<ul class="clean-list">\s*{% for m in item\.result\.maintainability_issues %}\s*<li>{{ m }}</li>\s*{% endfor %}\s*</ul>\s*</section>',
        '''<section class="mini-panel">
                            <h3>Maintainability Issues</h3>
                            {% if item.result.maintainability_issues %}
                            <ul class="clean-list">
                                {% for m in item.result.maintainability_issues %}
                                <li>{{ m }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No maintainability issues found.</p>
                            {% endif %}
                        </section>'''
    ),
    (
        r'<section class="mini-panel">\s*<h3>Documentation Issues</h3>\s*<ul class="clean-list">\s*{% for d in item\.result\.documentation_issues %}\s*<li>{{ d }}</li>\s*{% endfor %}\s*</ul>\s*</section>',
        '''<section class="mini-panel">
                            <h3>Documentation Issues</h3>
                            {% if item.result.documentation_issues %}
                            <ul class="clean-list">
                                {% for d in item.result.documentation_issues %}
                                <li>{{ d }}</li>
                                {% endfor %}
                            </ul>
                            {% else %}
                            <p class="empty-state">No documentation issues found.</p>
                            {% endif %}
                        </section>'''
    ),
    (
        r'<section class="wide-panel">\s*<h3>Suggestions</h3>\s*<ul class="clean-list">\s*{% for s in item\.result\.suggestions %}\s*<li>{{ s }}</li>\s*{% endfor %}\s*</ul>\s*</section>',
        '''<section class="wide-panel">
                        <h3>Suggestions</h3>
                        {% if item.result.suggestions %}
                        <ul class="clean-list">
                            {% for s in item.result.suggestions %}
                            <li>{{ s }}</li>
                            {% endfor %}
                        </ul>
                        {% else %}
                        <p class="empty-state">No suggestions available.</p>
                        {% endif %}
                    </section>'''
    ),
    (
        r'<section class="wide-panel">\s*<h3>Improved Code</h3>\s*<div class="code-wrap">\s*<button class="copy-btn" type="button" onclick="copyText\(this\)">Copy</button>\s*<pre class="code-block">{{ item\.result\.improved_code }}</pre>\s*</div>\s*</section>',
        '''<section class="wide-panel">
                        <h3>Improved Code</h3>
                        {% if item.result.improved_code %}
                        <div class="code-wrap">
                            <button class="copy-btn" type="button" onclick="copyText(this)">Copy</button>
                            <pre class="code-block">{{ item.result.improved_code }}</pre>
                        </div>
                        {% else %}
                        <p class="empty-state">No revised code available.</p>
                        {% endif %}
                    </section>'''
    ),
    (
        r'<section class="summary-box">\s*<h3>Summary</h3>\s*<p>{{ item\.result\.summary }}</p>\s*</section>',
        '''<section class="summary-box">
                        <h3>Summary</h3>
                        <p>{{ item.result.summary or "Review completed." }}</p>
                    </section>'''
    ),
]

replaced_counts = []
for pattern, repl in patterns:
    html, count = re.subn(pattern, repl, html, flags=re.DOTALL)
    replaced_counts.append(count)

target.write_text(html, encoding="utf-8")

print("\nReplacement counts:")
for i, c in enumerate(replaced_counts, 1):
    print(f"{i}. {c}")

# 5) 验证
updated = target.read_text(encoding="utf-8")

checks = [
    'No bugs found.',
    'No style issues found.',
    'No maintainability issues found.',
    'No documentation issues found.',
    'No suggestions available.',
    'No revised code available.',
    '.empty-state {'
]

print("\nVerification:")
for chk in checks:
    print(f"{chk}: {'OK' if chk in updated else 'MISSING'}")

print("\nDone. Restart Flask and hard refresh your browser (Ctrl+Shift+R).")
# Out:
# Found index.html files:
# 1. index.html
#
# Using template: index.html
# Backup created: index.html.bak
#
# Replacement counts:
# 1. 1
# 2. 1
# 3. 1
# 4. 1
# 5. 1
# 6. 1
# 7. 1
#
# Verification:
# No bugs found.: OK
# No style issues found.: OK
# No maintainability issues found.: OK
# No documentation issues found.: OK
# No suggestions available.: OK
# No revised code available.: OK
# .empty-state {: OK
#
# Done. Restart Flask and hard refresh your browser (Ctrl+Shift+R).
